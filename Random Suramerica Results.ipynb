# %% [markdown]
# ## Resultados

# %% [markdown]
# Cargamos los resultados de iterar todos los conjuntos de indicadores

# %%
import pandas as pd
import numpy as np
import time
import plotly.plotly as py
import plotly.graph_objs as go

df0 = pd.read_csv("suramerica_random_log.csv").drop(['Unnamed: 0'], 1)
df1 = pd.read_csv("suramerica_random_log_1.csv").drop(['Unnamed: 0'], 1)
df2 = pd.read_csv("suramerica_random_log_2.csv").drop(['Unnamed: 0'], 1)
df2 = df2.drop(df2.index[[357]])
df3 = pd.read_csv("suramerica_random_log_3.csv").drop(['Unnamed: 0'], 1)
df4 = pd.read_csv("suramerica_random_log_4.csv").drop(['Unnamed: 0'], 1)

df = pd.concat([df0,df1,df2,df3,df4], ignore_index=True)

df.to_csv('suramerica_results_random.csv')
df
# Out:
#             Base       Target  Look Back  Reg         %         Time  \
# 0    Agricultura  Agricultura          1   48  0.753705   349.043561
# 1    Agricultura  Agricultura          2   48  0.773581   428.586878
# 2    Agricultura  Agricultura          3   48  0.781177   400.207380
# 3    Agricultura     Ambiente          1   96  0.662694   712.719513
# 4    Agricultura     Ambiente          2   96  0.688307   789.752628
# 5    Agricultura     Ambiente          3   96  0.688740   860.206798
# 6    Agricultura        Ayuda          1   71  0.588951   719.062112
# 7    Agricultura        Ayuda          2   71  0.526452  2373.526615
# 8    Agricultura        Ayuda          3   71  0.562249  1618.591107
# 9    Agricultura      Ciencia          1   13  0.834891   103.733871
# 10   Agricultura      Ciencia          2   13  0.795768    84.797179
# 11   Agricultura      Ciencia          3   13  0.808986   145.125718
# 12   Agricultura        Clima          1   67  0.786392   423.227577
# 13   Agricultura        Clima          2   67  0.759068   470.426518
# 14   Agricultura        Clima          3   67  0.701549   587.298610
# 15   Agricultura     Comercio          1  142  0.731830  1450.490380
# 16   Agricultura     Comercio          2  142  0.734358  1478.661886
# 17   Agricultura     Comercio          3  142  0.715270  1714.168152
# 18   Agricultura        Deuda          1  229  0.576232  2379.877449
# 19   Agricultura        Deuda          2  229  0.610632  2413.893578
# 20   Agricultura        Deuda          3  229  0.596942  2613.753882
# 21   Agricultura     Economia          1  258  0.756927  2055.430365
# 22   Agricultura     Economia          2  258  0.756735  2442.076892
# 23   Agricultura     Economia          3  258  0.748159  2714.837575
# 24   Agricultura    Educacion          1  168  0.706649  1254.597385
# 25   Agricultura    Educacion          2  168  0.681659  1364.898308
# 26   Agricultura    Educacion          3  168  0.696744  1441.565790
# 27   Agricultura      Energia          1   51  0.754120   424.415514
# 28   Agricultura      Energia          2   51  0.754488   518.261306
# 29   Agricultura      Energia          3   51  0.742982   550.489463
# ..           ...          ...        ...  ...       ...          ...
# 460     Economia      Pobreza          2   25  0.705997   302.984923
# 461     Economia      Pobreza          3   25  0.612981   333.192866
# 462     Economia      Privado          1  162  0.691091  2078.068209
# 463     Economia      Privado          2  162  0.640853  2753.333700
# 464     Economia      Privado          3  162  0.679714  3345.078007
# 465     Economia      Publico          1   94  0.839336   700.387500
# 466     Economia      Publico          2   94  0.829199   995.303244
# 467     Economia      Publico          3   94  0.845108   961.271809
# 468     Economia        Salud          1  152  0.569412  1567.046733
# 469     Economia        Salud          2  152  0.602072  1890.872963
# 470     Economia        Salud          3  152  0.575064  2277.225869
# 471     Economia       Social          1   35  0.661911   457.049866
# 472     Economia       Social          2   35  0.698545   449.554458
# 473     Economia       Social          3   35  0.699433   613.736603
# 474     Economia      Trabajo          1  133  0.590396  1793.032303
# 475     Economia      Trabajo          2  133  0.574019  2006.456036
# 476     Economia      Trabajo          3  133  0.609988  2173.781632
# 477     Economia       Urbano          1   24  0.767528   206.637164
# 478     Economia       Urbano          2   24  0.746587   229.519399
# 479     Economia       Urbano          3   24  0.769206   390.171289
# 480    Educacion  Agricultura          1   48  0.582339   572.096537
# 481    Educacion  Agricultura          2   48  0.637082   628.547537
# 482    Educacion  Agricultura          3   48  0.689919   660.445098
# 483    Educacion     Ambiente          1  112  0.598619  1152.315598
# 484    Educacion     Ambiente          2  112  0.592648  1283.943200
# 485    Educacion     Ambiente          3  112  0.564981  1495.517092
# 486    Educacion        Ayuda          1   69  0.484593   878.014804
# 487    Educacion        Ayuda          2   69  0.512690  1044.905606
# 488    Educacion        Ayuda          3   69  0.508654  1094.194369
# 489    Educacion      Ciencia          1   13  0.766870   117.633919
#
#                                                Results
# 0    [[ 0.47820455]\n [ 0.93265366]\n [ 0.12911681]...
# 1    [[ 0.82121739]\n [ 0.91761199]\n [ 0.65325536]...
# 2    [[ 0.80781831]\n [ 0.9232483 ]\n [ 0.69848153]...
# 3    [[ 0.55962093]\n [ 0.57642369]\n [ 0.80735617]...
# 4    [[ 0.64737653]\n [ 0.90532119]\n [ 0.45288735]...
# 5    [[ 0.51461438]\n [ 0.61184616]\n [ 0.84671092]...
# 6    [[ 1.        ]\n [ 0.56313729]\n [ 0.934331  ]...
# 7    [[ 1.        ]\n [ 0.91444867]\n [ 0.27922554]...
# 8    [[ 1.        ]\n [ 0.92068346]\n [ 0.        ]...
# 9    [[ 0.96581034]\n [ 0.91934647]\n [ 0.54683333]...
# 10   [[ 0.93709384]\n [ 0.95883239]\n [ 0.56600422]...
# 11   [[ 0.96163966]\n [ 0.47515298]\n [ 0.87903694]...
# 12   [[ 0.4788377 ]\n [ 0.96397913]\n [ 0.50735333]...
# 13   [[ 0.77359398]\n [ 0.        ]\n [ 0.39981041]...
# 14   [[ 0.73981535]\n [ 0.        ]\n [ 0.        ]...
# 15   [[  0.00000000e+00]\n [  3.90819628e-01]\n [  ...
# 16   [[ 0.        ]\n [ 0.77990637]\n [ 0.01633911]...
# 17   [[ 0.        ]\n [ 0.60091079]\n [ 0.01664663]...
# 18   [[ 0.12398182]\n [ 0.11479351]\n [ 0.12353353]...
# 19   [[ 0.47507359]\n [ 0.03452455]\n [ 0.54821753]...
# 20   [[ 0.10297244]\n [ 0.        ]\n [ 0.        ]...
# 21   [[ 0.01320636]\n [ 0.96593833]\n [ 0.89120981]...
# 22   [[ 0.01204497]\n [ 0.93406228]\n [ 0.91023103]...
# 23   [[ 0.28256173]\n [ 0.95555865]\n [ 0.69188234]...
# 24   [[ 0.73298043]\n [ 0.77619353]\n [ 0.81110307]...
# 25   [[ 0.5543929 ]\n [ 0.78597867]\n [ 0.38184254]...
# 26   [[ 0.66824367]\n [ 0.64434874]\n [ 0.45924632]...
# 27   [[ 0.75103351]\n [ 0.60510672]\n [ 0.40909605]...
# 28   [[ 0.91676008]\n [ 0.45735883]\n [ 0.93317688]...
# 29   [[ 0.87779759]\n [ 0.32063442]\n [ 0.74139643]...
# ..                                                 ...
# 460  [[ 0.68619085]\n [ 0.        ]\n [ 0.61788245]...
# 461  [[ 0.        ]\n [ 0.        ]\n [ 0.60292041]...
# 462  [[ 0.82216446]\n [ 0.84903311]\n [ 0.        ]...
# 463  [[ 0.79441281]\n [ 0.75761011]\n [ 0.        ]...
# 464  [[ 0.84404883]\n [ 0.70195711]\n [ 0.        ]...
# 465  [[ 0.86747504]\n [ 0.94355649]\n [ 0.        ]...
# 466  [[ 0.87390007]\n [ 0.95437572]\n [ 0.        ]...
# 467  [[ 0.89938837]\n [ 0.93884229]\n [ 0.        ]...
# 468  [[ 0.        ]\n [ 0.93311874]\n [ 0.94849326]...
# 469  [[ 0.        ]\n [ 0.92673624]\n [ 0.91665667]...
# 470  [[ 0.        ]\n [ 0.93046784]\n [ 0.93456217]...
# 471  [[ 0.93344528]\n [ 0.56346607]\n [ 0.77508202]...
# 472  [[  9.65507333e-01]\n [  2.54202608e-02]\n [  ...
# 473  [[ 0.97005356]\n [ 0.        ]\n [ 0.40984753]...
# 474  [[ 0.        ]\n [ 0.        ]\n [ 0.00689547]...
# 475  [[ 0.        ]\n [ 0.        ]\n [ 0.        ]...
# 476  [[ 0.05424519]\n [ 0.20740022]\n [ 0.30151596]...
# 477  [[ 0.61806504]\n [ 0.74246031]\n [ 0.96519674]...
# 478  [[ 0.        ]\n [ 0.48175405]\n [ 0.91229502]...
# 479  [[ 0.34526686]\n [ 0.86854256]\n [ 0.92334861]...
# 480  [[ 0.34048961]\n [ 0.        ]\n [ 0.25990772]...
# 481  [[ 0.30047114]\n [ 0.5455638 ]\n [ 0.65027224]...
# 482  [[ 0.41448622]\n [ 0.3546245 ]\n [ 0.52589257]...
# 483  [[ 0.2799016 ]\n [ 0.96379888]\n [ 0.74684808]...
# 484  [[ 0.36049661]\n [ 0.74470988]\n [ 0.88164039]...
# 485  [[ 0.47191024]\n [ 0.53573165]\n [ 0.75232298]...
# 486  [[ 1.        ]\n [ 0.71794062]\n [ 0.        ]...
# 487  [[ 1.        ]\n [ 0.51581611]\n [ 0.30223108]...
# 488  [[ 1.        ]\n [ 0.91362482]\n [ 0.98392858]...
# 489  [[ 0.80366876]\n [ 0.53738042]\n [ 0.03955398]...
#
# [490 rows x 7 columns]

# %%
pd.read_csv("suramerica_results_random.csv")
# Out:
#      Unnamed: 0         Base       Target  Look Back  Reg         %  \
# 0             0  Agricultura  Agricultura          1   48  0.753705
# 1             1  Agricultura  Agricultura          2   48  0.773581
# 2             2  Agricultura  Agricultura          3   48  0.781177
# 3             3  Agricultura     Ambiente          1   96  0.662694
# 4             4  Agricultura     Ambiente          2   96  0.688307
# 5             5  Agricultura     Ambiente          3   96  0.688740
# 6             6  Agricultura        Ayuda          1   71  0.588951
# 7             7  Agricultura        Ayuda          2   71  0.526452
# 8             8  Agricultura        Ayuda          3   71  0.562249
# 9             9  Agricultura      Ciencia          1   13  0.834891
# 10           10  Agricultura      Ciencia          2   13  0.795768
# 11           11  Agricultura      Ciencia          3   13  0.808986
# 12           12  Agricultura        Clima          1   67  0.786392
# 13           13  Agricultura        Clima          2   67  0.759068
# 14           14  Agricultura        Clima          3   67  0.701549
# 15           15  Agricultura     Comercio          1  142  0.731830
# 16           16  Agricultura     Comercio          2  142  0.734358
# 17           17  Agricultura     Comercio          3  142  0.715270
# 18           18  Agricultura        Deuda          1  229  0.576232
# 19           19  Agricultura        Deuda          2  229  0.610632
# 20           20  Agricultura        Deuda          3  229  0.596942
# 21           21  Agricultura     Economia          1  258  0.756927
# 22           22  Agricultura     Economia          2  258  0.756735
# 23           23  Agricultura     Economia          3  258  0.748159
# 24           24  Agricultura    Educacion          1  168  0.706649
# 25           25  Agricultura    Educacion          2  168  0.681659
# 26           26  Agricultura    Educacion          3  168  0.696744
# 27           27  Agricultura      Energia          1   51  0.754120
# 28           28  Agricultura      Energia          2   51  0.754488
# 29           29  Agricultura      Energia          3   51  0.742982
# ..          ...          ...          ...        ...  ...       ...
# 460         460     Economia      Pobreza          2   25  0.705997
# 461         461     Economia      Pobreza          3   25  0.612981
# 462         462     Economia      Privado          1  162  0.691091
# 463         463     Economia      Privado          2  162  0.640853
# 464         464     Economia      Privado          3  162  0.679714
# 465         465     Economia      Publico          1   94  0.839336
# 466         466     Economia      Publico          2   94  0.829199
# 467         467     Economia      Publico          3   94  0.845108
# 468         468     Economia        Salud          1  152  0.569412
# 469         469     Economia        Salud          2  152  0.602072
# 470         470     Economia        Salud          3  152  0.575064
# 471         471     Economia       Social          1   35  0.661911
# 472         472     Economia       Social          2   35  0.698545
# 473         473     Economia       Social          3   35  0.699433
# 474         474     Economia      Trabajo          1  133  0.590396
# 475         475     Economia      Trabajo          2  133  0.574019
# 476         476     Economia      Trabajo          3  133  0.609988
# 477         477     Economia       Urbano          1   24  0.767528
# 478         478     Economia       Urbano          2   24  0.746587
# 479         479     Economia       Urbano          3   24  0.769206
# 480         480    Educacion  Agricultura          1   48  0.582339
# 481         481    Educacion  Agricultura          2   48  0.637082
# 482         482    Educacion  Agricultura          3   48  0.689919
# 483         483    Educacion     Ambiente          1  112  0.598619
# 484         484    Educacion     Ambiente          2  112  0.592648
# 485         485    Educacion     Ambiente          3  112  0.564981
# 486         486    Educacion        Ayuda          1   69  0.484593
# 487         487    Educacion        Ayuda          2   69  0.512690
# 488         488    Educacion        Ayuda          3   69  0.508654
# 489         489    Educacion      Ciencia          1   13  0.766870
#
#             Time                                            Results
# 0     349.043561  [[ 0.47820455]\n [ 0.93265366]\n [ 0.12911681]...
# 1     428.586878  [[ 0.82121739]\n [ 0.91761199]\n [ 0.65325536]...
# 2     400.207380  [[ 0.80781831]\n [ 0.9232483 ]\n [ 0.69848153]...
# 3     712.719513  [[ 0.55962093]\n [ 0.57642369]\n [ 0.80735617]...
# 4     789.752628  [[ 0.64737653]\n [ 0.90532119]\n [ 0.45288735]...
# 5     860.206798  [[ 0.51461438]\n [ 0.61184616]\n [ 0.84671092]...
# 6     719.062112  [[ 1.        ]\n [ 0.56313729]\n [ 0.934331  ]...
# 7    2373.526615  [[ 1.        ]\n [ 0.91444867]\n [ 0.27922554]...
# 8    1618.591107  [[ 1.        ]\n [ 0.92068346]\n [ 0.        ]...
# 9     103.733871  [[ 0.96581034]\n [ 0.91934647]\n [ 0.54683333]...
# 10     84.797179  [[ 0.93709384]\n [ 0.95883239]\n [ 0.56600422]...
# 11    145.125718  [[ 0.96163966]\n [ 0.47515298]\n [ 0.87903694]...
# 12    423.227577  [[ 0.4788377 ]\n [ 0.96397913]\n [ 0.50735333]...
# 13    470.426518  [[ 0.77359398]\n [ 0.        ]\n [ 0.39981041]...
# 14    587.298610  [[ 0.73981535]\n [ 0.        ]\n [ 0.        ]...
# 15   1450.490380  [[  0.00000000e+00]\n [  3.90819628e-01]\n [  ...
# 16   1478.661886  [[ 0.        ]\n [ 0.77990637]\n [ 0.01633911]...
# 17   1714.168152  [[ 0.        ]\n [ 0.60091079]\n [ 0.01664663]...
# 18   2379.877449  [[ 0.12398182]\n [ 0.11479351]\n [ 0.12353353]...
# 19   2413.893578  [[ 0.47507359]\n [ 0.03452455]\n [ 0.54821753]...
# 20   2613.753882  [[ 0.10297244]\n [ 0.        ]\n [ 0.        ]...
# 21   2055.430365  [[ 0.01320636]\n [ 0.96593833]\n [ 0.89120981]...
# 22   2442.076892  [[ 0.01204497]\n [ 0.93406228]\n [ 0.91023103]...
# 23   2714.837575  [[ 0.28256173]\n [ 0.95555865]\n [ 0.69188234]...
# 24   1254.597385  [[ 0.73298043]\n [ 0.77619353]\n [ 0.81110307]...
# 25   1364.898308  [[ 0.5543929 ]\n [ 0.78597867]\n [ 0.38184254]...
# 26   1441.565790  [[ 0.66824367]\n [ 0.64434874]\n [ 0.45924632]...
# 27    424.415514  [[ 0.75103351]\n [ 0.60510672]\n [ 0.40909605]...
# 28    518.261306  [[ 0.91676008]\n [ 0.45735883]\n [ 0.93317688]...
# 29    550.489463  [[ 0.87779759]\n [ 0.32063442]\n [ 0.74139643]...
# ..           ...                                                ...
# 460   302.984923  [[ 0.68619085]\n [ 0.        ]\n [ 0.61788245]...
# 461   333.192866  [[ 0.        ]\n [ 0.        ]\n [ 0.60292041]...
# 462  2078.068209  [[ 0.82216446]\n [ 0.84903311]\n [ 0.        ]...
# 463  2753.333700  [[ 0.79441281]\n [ 0.75761011]\n [ 0.        ]...
# 464  3345.078007  [[ 0.84404883]\n [ 0.70195711]\n [ 0.        ]...
# 465   700.387500  [[ 0.86747504]\n [ 0.94355649]\n [ 0.        ]...
# 466   995.303244  [[ 0.87390007]\n [ 0.95437572]\n [ 0.        ]...
# 467   961.271809  [[ 0.89938837]\n [ 0.93884229]\n [ 0.        ]...
# 468  1567.046733  [[ 0.        ]\n [ 0.93311874]\n [ 0.94849326]...
# 469  1890.872963  [[ 0.        ]\n [ 0.92673624]\n [ 0.91665667]...
# 470  2277.225869  [[ 0.        ]\n [ 0.93046784]\n [ 0.93456217]...
# 471   457.049866  [[ 0.93344528]\n [ 0.56346607]\n [ 0.77508202]...
# 472   449.554458  [[  9.65507333e-01]\n [  2.54202608e-02]\n [  ...
# 473   613.736603  [[ 0.97005356]\n [ 0.        ]\n [ 0.40984753]...
# 474  1793.032303  [[ 0.        ]\n [ 0.        ]\n [ 0.00689547]...
# 475  2006.456036  [[ 0.        ]\n [ 0.        ]\n [ 0.        ]...
# 476  2173.781632  [[ 0.05424519]\n [ 0.20740022]\n [ 0.30151596]...
# 477   206.637164  [[ 0.61806504]\n [ 0.74246031]\n [ 0.96519674]...
# 478   229.519399  [[ 0.        ]\n [ 0.48175405]\n [ 0.91229502]...
# 479   390.171289  [[ 0.34526686]\n [ 0.86854256]\n [ 0.92334861]...
# 480   572.096537  [[ 0.34048961]\n [ 0.        ]\n [ 0.25990772]...
# 481   628.547537  [[ 0.30047114]\n [ 0.5455638 ]\n [ 0.65027224]...
# 482   660.445098  [[ 0.41448622]\n [ 0.3546245 ]\n [ 0.52589257]...
# 483  1152.315598  [[ 0.2799016 ]\n [ 0.96379888]\n [ 0.74684808]...
# 484  1283.943200  [[ 0.36049661]\n [ 0.74470988]\n [ 0.88164039]...
# 485  1495.517092  [[ 0.47191024]\n [ 0.53573165]\n [ 0.75232298]...
# 486   878.014804  [[ 1.        ]\n [ 0.71794062]\n [ 0.        ]...
# 487  1044.905606  [[ 1.        ]\n [ 0.51581611]\n [ 0.30223108]...
# 488  1094.194369  [[ 1.        ]\n [ 0.91362482]\n [ 0.98392858]...
# 489   117.633919  [[ 0.80366876]\n [ 0.53738042]\n [ 0.03955398]...
#
# [490 rows x 8 columns]

# %% [markdown]
# ## Resultados iniciales

# %%
pd.DataFrame.pivot_table(df, index=["Base","Target","Reg"], columns=["Look Back"]).drop(['Time'],1)
# Out:
#                                         %
# Look Back                               1         2         3
# Base        Target          Reg
# Agricultura Agricultura     48   0.753705  0.773581  0.781177
#             Ambiente        96   0.662694  0.688307  0.688740
#             Ayuda           71   0.588951  0.526452  0.562249
#             Ciencia         13   0.834891  0.795768  0.808986
#             Clima           67   0.786392  0.759068  0.701549
#             Comercio        142  0.731830  0.734358  0.715270
#             Deuda           229  0.576232  0.610632  0.596942
#             Economia        258  0.756927  0.756735  0.748159
#             Educacion       168  0.706649  0.681659  0.696744
#             Energia         51   0.754120  0.754488  0.742982
#             Finanzas        67   0.681017  0.639754  0.663964
#             Genero          175  0.608040  0.584120  0.605041
#             Infraestructura 41   0.702746  0.721176  0.718914
#             Pobreza         23   0.670181  0.567439  0.588481
#             Privado         163  0.663004  0.657962  0.663694
#             Publico         97   0.812875  0.734692  0.794907
#             Salud           150  0.553191  0.572100  0.562467
#             Social          35   0.695702  0.683202  0.691386
#             Trabajo         130  0.567317  0.592773  0.574008
#             Urbano          24   0.775111  0.855256  0.774646
# Ambiente    Agricultura     32   0.732564  0.762933  0.806707
#             Ambiente        112  0.690196  0.695175  0.689222
#             Ayuda           71   0.517192  0.491844  0.530590
#             Ciencia         13   0.682875  0.830603  0.859583
#             Clima           31   0.793605  0.762934  0.810201
#             Comercio        144  0.700381  0.700983  0.728230
#             Deuda           229  0.563841  0.540902  0.554636
#             Economia        239  0.717078  0.756575  0.741549
#             Educacion       168  0.623104  0.657060  0.688070
#             Energia         31   0.713086  0.725228  0.771068
# ...                                   ...       ...       ...
# Deuda       Privado         165  0.570002  0.588835  0.604955
#             Publico         97   0.690714  0.666062  0.764473
#             Salud           152  0.516991  0.518136  0.544014
#             Social          35   0.612310  0.632611  0.636675
#             Trabajo         133  0.533420  0.539447  0.521041
#             Urbano          24   0.697427  0.646923  0.699332
# Economia    Agricultura     46   0.740202  0.773689  0.707721
#             Ambiente        91   0.706007  0.664590  0.635116
#             Ayuda           66   0.549285  0.566560  0.611366
#             Ciencia         11   0.747061  0.879495  0.895316
#             Clima           78   0.717481  0.789884  0.743342
#             Comercio        112  0.741481  0.715455  0.717590
#             Deuda           203  0.584370  0.571832  0.563168
#             Economia        260  0.811801  0.834132  0.810683
#             Educacion       168  0.676378  0.723615  0.685800
#             Energia         48   0.749358  0.790384  0.754698
#             Finanzas        51   0.690317  0.656474  0.743007
#             Genero          177  0.641250  0.631612  0.640129
#             Infraestructura 41   0.730434  0.716602  0.715701
#             Pobreza         25   0.637865  0.705997  0.612981
#             Privado         162  0.691091  0.640853  0.679714
#             Publico         94   0.839336  0.829199  0.845108
#             Salud           152  0.569412  0.602072  0.575064
#             Social          35   0.661911  0.698545  0.699433
#             Trabajo         133  0.590396  0.574019  0.609988
#             Urbano          24   0.767528  0.746587  0.769206
# Educacion   Agricultura     48   0.582339  0.637082  0.689919
#             Ambiente        112  0.598619  0.592648  0.564981
#             Ayuda           69   0.484593  0.512690  0.508654
#             Ciencia         13   0.766870       NaN       NaN
#
# [164 rows x 3 columns]

# %%
datos = pd.read_csv("suramerica.csv").drop('Unnamed: 0', 1)
paises = datos['CountryCode'].drop_duplicates().values.tolist()
pais_nombre = 'Suramerica'

preprocessing = 'imput'
search = 'random'
year_init = 2012
year_range = 5
look_back = 3
years = range(year_init-year_range+1,year_init+1)[::-1]

agricultura     = open("Indicadores/iagricultura.txt").read().split(',')
ambiente        = open("Indicadores/iambiente.txt").read().split(',')
ayuda           = open("Indicadores/iayuda.txt").read().split(',')
ciencia         = open("Indicadores/iciencia.txt").read().split(',')
clima           = open("Indicadores/iclima.txt").read().split(',')
comercio        = open("Indicadores/icomercio.txt").read().split(',')
deuda           = open("Indicadores/ideuda.txt").read().split(',')
economia        = open("Indicadores/ieconomia.txt").read().split(',')
educacion       = open("Indicadores/ieducacion.txt").read().split(',')
energia         = open("Indicadores/ienergia.txt").read().split(',')
finanzas        = open("Indicadores/ifinanzas.txt").read().split(',')
genero          = open("Indicadores/igenero.txt").read().split(',')
infraestructura = open("Indicadores/iinfraestructura.txt").read().split(',')
pobreza         = open("Indicadores/ipobreza.txt").read().split(',')
privado         = open("Indicadores/iprivado.txt").read().split(',')
publico         = open("Indicadores/ipublico.txt").read().split(',')
salud           = open("Indicadores/isalud.txt").read().split(',')
social          = open("Indicadores/isocial.txt").read().split(',')
trabajo         = open("Indicadores/itrabajo.txt").read().split(',')
urbano          = open("Indicadores/iurbano.txt").read().split(',')


conjunto_nombre = ['Agricultura','Ambiente','Ayuda','Ciencia','Clima','Comercio','Deuda','Economia','Educacion',
                   'Energia','Finanzas','Genero','Infraestructura','Pobreza','Privado','Publico','Salud','Social',
                   'Trabajo','Urbano']
conjunto = [agricultura,ambiente,ayuda,ciencia,clima,comercio,deuda,economia,educacion,energia,finanzas,genero,
            infraestructura,pobreza,privado,publico,salud,social,trabajo,urbano]

# %%
def tabla_base(indicadores):
    tab = pd.DataFrame.pivot_table(datos, values='Value', index=['CountryCode', 'Year'], columns=['IndicatorCode']).loc[(paises,years),indicadores].sortlevel(["CountryCode","Year"], ascending=[True,False])
    return tab

# %%
def buscar_mejores(df):
    return df[df.Resultados > 0.9].reset_index(drop=True)

# %%
def graficar_resultados(df,look_back):

    trace = go.Heatmap(z=df[df['Look Back'] == look_back]['%'],
                       x=df[df['Look Back'] == look_back]['Base'],
                       y=df[df['Look Back'] == look_back]['Target'],
                       zmax=1.0,
                       zmin=0.0,
                       colorscale = 'Viridis')
    data=[trace]
    
    layout = go.Layout(
        title=pais_nombre+' + '+search+': Total Heatmap with Look Back = '+str(look_back),
        xaxis=dict(title='Base',   titlefont=dict(size=18)),
        yaxis=dict(title='Target', titlefont=dict(size=18))
    )
    
    fig = go.Figure(data=data, layout=layout)

    return py.iplot(fig,filename=pais_nombre+' + '+search+': Total Heatmap with Look Back = '+str(look_back))

# %%
def buscar_resultados(df,indicador_1,indicador_2,look_back):
    #Buscamos Resultados en base al conjunto de indicadores Base, Target y Look Back
    temp = df[(df['Base']==indicador_1)&(df['Target']==indicador_2)&(df['Look Back'] == look_back)]['Results'].values[0]
    df_temp = temp.replace("'","").replace("[","").replace("]","").replace(" ","").split('\n')
    results = []
    for i in df_temp: 
        results.append(float(i))
    
    # Códigos de los indicadores con registros 
    df_nombres = pd.DataFrame(conjunto_nombre, columns=['Resultados'])
    indicador_1 = conjunto[df_nombres[df_nombres['Resultados']==indicador_1].index.values[0]]
    indicador_2 = conjunto[df_nombres[df_nombres['Resultados']==indicador_2].index.values[0]]     
    df = pd.DataFrame(indicador_2)
    
    # Filtro indicadores repetidos
    if(indicador_1!=indicador_2):
        indicador_2 = np.array(df.loc[~df.ix[:,0].isin(indicador_1)]).flatten()
    df_zeros = tabla_base(indicador_2).dropna(how='all',axis=1)
    icodes = df_zeros.columns.values

    # Buscamos Nombres de los Códigos de los Indicadores
    nombres = pd.DataFrame(datos).loc[:,['IndicatorName','IndicatorCode']].set_index('IndicatorCode').loc[icodes].drop_duplicates()

    # Concatenamos Resultados y Nombres, Reindexando en base a los nombres
    df_results = pd.DataFrame(np.column_stack([nombres,results]),columns=['Indicadores','Resultados'])
    
    return df_results

# %%
def graficar_resultados_individuales(df,indicador_base,indicador_target,look_back):

    df_temp = buscar_resultados(df,indicador_base,indicador_target,look_back)

    data = [go.Bar(
                x= df_temp['Indicadores'],
                y= df_temp['Resultados'],

        marker=dict(     
            color = df_temp['Resultados'].values,
            colorscale ='Viridis',
            showscale = True
            ),
        )]

    layout = go.Layout(
        title='Result to predict: '+indicador_target+' from '+indicador_base+' with '+'Look Back = '+str(look_back),
    )
    
    fig = go.Figure(data=data, layout=layout)

    return py.iplot(fig, filename = 'Result to predict: '+indicador_target+' from '+indicador_base+' with '+'Look Back = '+str(look_back))

# %%
def conjuntos_predecibles(df,look_back):
    df_temp = pd.DataFrame.pivot_table( df[df['Look Back'] == 1].drop(['Time','Reg','Results'],1) , index=["Target","Base"], columns=["Look Back"])
    return pd.DataFrame(df_temp[df_temp['%'] > 0.3].count(level=0).sort_values([('%',1)], ascending=False).index.values, columns=["Conjunto"])

# %%
def conjuntos_predictores(df,look_back):
    df_temp = pd.DataFrame.pivot_table( df[df['Look Back'] == 1].drop(['Time','Reg','Results'],1) , index=["Base","Target"], columns=["Look Back"])
    return pd.DataFrame(df_temp[df_temp['%'] > 0.3].count(level=0).sort_values([('%',1)], ascending=False).index.values, columns=["Conjunto"])

# %% [markdown]
# ## Buscamos Mejores Resultados Individuales

# %%
buscar_mejores(buscar_resultados(df,'Agricultura','Infraestructura',1))
# Out:
#                                           Indicadores Resultados
# 0   Container port traffic (TEU: 20 foot equivalen...   0.929354
# 1         Electric power consumption (kWh per capita)   0.979183
# 2   Electric power transmission and distribution l...   0.927559
# 3   Electricity production from coal sources (% of...   0.921043
# 4   Electricity production from hydroelectric sour...     0.9139
# 5   Electricity production from natural gas source...   0.931298
# 6   Electricity production from oil sources (% of ...   0.914689
# 7                       Fixed telephone subscriptions   0.939922
# 8      Fixed telephone subscriptions (per 100 people)   0.932202
# 9           ICT goods imports (% total goods imports)   0.903299
# 10             ICT service exports (BoP, current US$)   0.935613
# 11  Improved water source (% of population with ac...   0.969606
# 12  Improved water source, urban (% of urban popul...   0.984854
# 13                    Internet users (per 100 people)   0.920151
# 14  Investment in telecoms with private participat...   0.981952
# 15                        Rail lines (total route-km)   0.975262

# %% [markdown]
# ## Mejores combinaciones

# %%
df.sort_values('%', ascending=False).reset_index().drop(['index','Time','Results'],1)[:10]
# Out:
#           Base   Target  Look Back  Reg         %
# 0     Comercio  Ciencia          1   11  0.924383
# 1     Comercio  Ciencia          2   11  0.920824
# 2     Comercio  Ciencia          3   11  0.903308
# 3      Ciencia  Ciencia          3   13  0.903255
# 4     Economia  Ciencia          3   11  0.895316
# 5     Economia  Ciencia          2   11  0.879495
# 6      Ciencia  Ciencia          1   13  0.873959
# 7        Clima  Ciencia          3   13  0.863778
# 8     Ambiente  Ciencia          3   13  0.859583
# 9  Agricultura   Urbano          2   24  0.855256

# %% [markdown]
# ## Peores combinaciones

# %%
df.sort_values('%', ascending=False).reset_index().drop(['index','Time','Results'],1).tail(10)
# Out:
#         Base   Target  Look Back  Reg         %
# 480  Ciencia  Trabajo          3  133  0.443954
# 481  Ciencia   Social          1   35  0.435801
# 482  Ciencia  Trabajo          2  133  0.426061
# 483  Ciencia   Genero          1  177  0.421308
# 484  Ciencia    Ayuda          2   71  0.418732
# 485  Ciencia    Salud          1  152  0.414636
# 486  Ciencia  Pobreza          1   25  0.404672
# 487  Ciencia    Ayuda          3   71  0.400140
# 488  Ciencia  Trabajo          1  133  0.395530
# 489  Ciencia    Ayuda          1   71  0.323534

# %% [markdown]
# ## Graficamos Resultados Individuales

# %% [markdown]
# Resultado de predecir el conjunto de indicadores de Infraestructura desde Agricultura

# %%
graficar_resultados_individuales(df,'Agricultura','Infraestructura',1)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ambigus9/200.embed" height="525px" width="100%"></iframe>

# %%
graficar_resultados_individuales(df,'Agricultura','Economia',1)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ambigus9/204.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Graficamos Resultados Globales

# %% [markdown]
# Este Heatmap nos muestra el porcentaje de cada conjunto indicadores que tiene un Score de R2 > 90% (0.9)

# %%
graficar_resultados(df,1)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ambigus9/232.embed" height="525px" width="100%"></iframe>

# %%
graficar_resultados(df,2)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ambigus9/236.embed" height="525px" width="100%"></iframe>

# %%
graficar_resultados(df,3)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ambigus9/240.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Conclusiones

# %% [markdown]
# - Con el objetivo de encontrar los conjuntos con mayor grado de predictibilidad, contamos la cantidad de conjuntos en los cuales el 30% o más de sus indicadores obtuvieron un puntaje mayor al 90% para dos casos:
#
#  **Predictor:** Conjunto que predice a otro conjunto
#
#  **Predecible:** Conjunto que es predecido por otro conjunto

# %%
pd.DataFrame(np.column_stack([conjuntos_predictores(df,1)[:5],conjuntos_predictores(df,1).tail(5),conjuntos_predecibles(df,1)[:5],conjuntos_predecibles(df,1).tail(5)]), columns=['Best Predictor','Worse Predictor','Easier Predictable','Hard Predictable'])
# Out:
#   Best Predictor Worse Predictor Easier Predictable Hard Predictable
# 0    Agricultura           Clima        Agricultura         Economia
# 1       Ambiente        Comercio              Ayuda            Deuda
# 2          Ayuda           Deuda            Ciencia         Comercio
# 3        Ciencia        Economia           Ambiente            Clima
# 4          Clima       Educacion    Infraestructura           Urbano
