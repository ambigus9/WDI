# %% [markdown]
# ## Grid Results Suramerica

# %% [markdown]
# Cargamos los resultados de iterar todos los conjuntos de indicadores

# %%
import pandas as pd
import numpy as np
import time
import plotly.plotly as py
import plotly.graph_objs as go

dfa = pd.read_csv("suramerica_grid_log.csv").drop(['Unnamed: 0'], 1)
dfb = pd.read_csv("suramerica_grid_logb.csv").drop(['Unnamed: 0'], 1)
dfc = pd.read_csv("suramerica_grid_logc.csv").drop(['Unnamed: 0'], 1)
dfd = pd.read_csv("suramerica_grid_logd.csv").drop(['Unnamed: 0'], 1)
df  = pd.concat([dfa,dfb,dfc,dfd], ignore_index=True)

df.to_csv('suramerica_results_grid.csv')
df
# Out:
#             Base       Target  Look Back  Reg         %         Time  \
# 0    Agricultura  Agricultura          1   48  0.796854   317.614283
# 1    Agricultura  Agricultura          2   48  0.752689   357.953047
# 2    Agricultura  Agricultura          3   48  0.791113   366.047166
# 3    Agricultura     Ambiente          1   96  0.725681   518.815343
# 4    Agricultura     Ambiente          2   96  0.740845   647.211091
# 5    Agricultura     Ambiente          3   96  0.660708   740.159734
# 6    Agricultura        Ayuda          1   71  0.576212   658.288962
# 7    Agricultura        Ayuda          2   71  0.558929   672.301449
# 8    Agricultura        Ayuda          3   71  0.544161   713.118803
# 9    Agricultura      Ciencia          1   13  0.900183    73.194680
# 10   Agricultura      Ciencia          2   13  0.823847    84.323329
# 11   Agricultura      Ciencia          3   13  0.809137   120.902273
# 12   Agricultura        Clima          1   67  0.741598   345.031057
# 13   Agricultura        Clima          2   67  0.744996   428.464407
# 14   Agricultura        Clima          3   67  0.742159   446.413451
# 15   Agricultura     Comercio          1  142  0.741123  1305.445068
# 16   Agricultura     Comercio          2  142  0.736872  1331.944374
# 17   Agricultura     Comercio          3  142  0.755783  1419.989223
# 18   Agricultura        Deuda          1  229  0.594924  2017.770631
# 19   Agricultura        Deuda          2  229  0.590460  2188.010175
# 20   Agricultura        Deuda          3  229  0.594468  2305.407494
# 21   Agricultura     Economia          1  258  0.779331  1786.728822
# 22   Agricultura     Economia          2  258  0.757347  2249.739706
# 23   Agricultura     Economia          3  258  0.777363  2297.819511
# 24   Agricultura    Educacion          1  168  0.667658  1092.241439
# 25   Agricultura    Educacion          2  168  0.677733  1185.156504
# 26   Agricultura    Educacion          3  168  0.688597  1255.838110
# 27   Agricultura      Energia          1   51  0.783531   384.934752
# 28   Agricultura      Energia          2   51  0.802873   418.261136
# 29   Agricultura      Energia          3   51  0.756724   387.269424
# ..           ...          ...        ...  ...       ...          ...
# 351     Comercio        Salud          2  152  0.556866  2305.304078
# 352     Comercio        Salud          3  152  0.558984  2374.361803
# 353     Comercio       Social          1   35  0.666930   577.888624
# 354     Comercio       Social          2   35  0.667839   685.695776
# 355     Comercio       Social          3   35  0.658631   775.632202
# 356     Comercio      Trabajo          1  133  0.540595  1871.903621
# 357     Comercio      Trabajo          2  133  0.564563  1398.761551
# 358     Comercio      Trabajo          3  133  0.564648  1552.102514
# 359     Comercio       Urbano          1   24  0.771297   165.920630
# 360     Comercio       Urbano          2   24  0.761219   168.319470
# 361     Comercio       Urbano          3   24  0.743623   221.105258
# 362        Deuda  Agricultura          1   48  0.633064   499.109859
# 363        Deuda  Agricultura          2   48  0.713830   576.499431
# 364        Deuda  Agricultura          3   48  0.666532   681.961546
# 365        Deuda     Ambiente          1  112  0.589236   972.777544
# 366        Deuda     Ambiente          2  112  0.595396  1131.591812
# 367        Deuda     Ambiente          3  112  0.606781  1404.294438
# 368        Deuda        Ayuda          1   64  0.496690   689.152560
# 369        Deuda        Ayuda          2   64  0.519129   886.568997
# 370        Deuda        Ayuda          3   64  0.539436   992.929456
# 371        Deuda      Ciencia          1   13  0.571689   131.407778
# 372        Deuda      Ciencia          2   13  0.749090   141.736034
# 373        Deuda      Ciencia          3   13  0.814192   122.579336
# 374        Deuda        Clima          1   80  0.639248   704.160780
# 375        Deuda        Clima          2   80  0.616638   935.248031
# 376        Deuda        Clima          3   80  0.687608  1001.109842
# 377        Deuda     Comercio          1  142  0.659228  1757.498001
# 378        Deuda     Comercio          2  142  0.638625  2218.896015
# 379        Deuda     Comercio          3  142  0.698511  2510.750705
# 380        Deuda        Deuda          1  229  0.646340  2308.982655
#
#                                                Results
# 0    [[ 0.92383091]\n [ 0.91891816]\n [ 0.77532557]...
# 1    [[ 0.6061266 ]\n [ 0.63911117]\n [ 0.96304798]...
# 2    [[ 0.73096749]\n [ 0.94134981]\n [ 0.64646321]...
# 3    [[ 0.84134101]\n [ 0.83863503]\n [ 0.86781816]...
# 4    [[ 0.67773474]\n [ 0.83584079]\n [ 0.42724829]...
# 5    [[ 0.44650489]\n [ 0.85000225]\n [ 0.49570112]...
# 6    [[ 1.        ]\n [ 0.38447523]\n [ 0.57544428]...
# 7    [[ 1.        ]\n [ 0.57315379]\n [ 0.32919573]...
# 8    [[ 1.        ]\n [ 0.94449653]\n [ 0.44195537]...
# 9    [[ 0.97111439]\n [ 0.9079542 ]\n [ 0.40772731]...
# 10   [[ 0.99011696]\n [ 0.8832398 ]\n [ 0.38871936]...
# 11   [[ 0.8522225 ]\n [ 0.91746977]\n [ 0.74558331]...
# 12   [[ 0.7408473 ]\n [ 0.        ]\n [ 0.        ]...
# 13   [[ 0.90188364]\n [ 0.        ]\n [ 0.        ]...
# 14   [[ 0.31235238]\n [ 0.68798788]\n [ 0.        ]...
# 15   [[ 0.        ]\n [ 0.69024777]\n [ 0.08174442]...
# 16   [[ 0.62582591]\n [ 0.57807023]\n [ 0.        ]...
# 17   [[ 0.        ]\n [ 0.        ]\n [ 0.27117775]...
# 18   [[ 0.11176048]\n [ 0.        ]\n [ 0.15535649]...
# 19   [[ 0.1893396 ]\n [ 0.        ]\n [ 0.18191585]...
# 20   [[ 0.02837808]\n [ 0.        ]\n [ 0.63947628]...
# 21   [[ 0.17652151]\n [ 0.99180388]\n [ 0.94924725]...
# 22   [[ 0.04067285]\n [ 0.96541623]\n [ 0.97190695]...
# 23   [[ 0.01903762]\n [ 0.91420289]\n [ 0.90941998]...
# 24   [[ 0.62306901]\n [ 0.69340892]\n [ 0.78156354]...
# 25   [[ 0.63183526]\n [ 0.79991716]\n [ 0.69329377]...
# 26   [[ 0.4375277 ]\n [ 0.8265811 ]\n [ 0.71881212]...
# 27   [[ 0.70311573]\n [ 0.17969168]\n [ 0.97427052]...
# 28   [[ 0.92135344]\n [ 0.49659986]\n [ 0.89927732]...
# 29   [[ 0.83479143]\n [ 0.60604567]\n [ 0.84107526]...
# ..                                                 ...
# 351  [[ 0.        ]\n [ 0.93352641]\n [ 0.91448675]...
# 352  [[ 0.        ]\n [ 0.94356716]\n [ 0.90794354]...
# 353  [[ 0.85056981]\n [ 0.78863241]\n [ 0.21427979]...
# 354  [[ 0.92235918]\n [ 0.52574543]\n [ 0.        ]...
# 355  [[ 0.90961127]\n [ 0.50229062]\n [ 0.52402005]...
# 356  [[ 0.11925468]\n [ 0.        ]\n [ 0.        ]...
# 357  [[ 0.        ]\n [ 0.        ]\n [ 0.        ]...
# 358  [[ 0.        ]\n [ 0.        ]\n [ 0.        ]...
# 359  [[ 0.        ]\n [ 0.54330109]\n [ 0.93992183]...
# 360  [[ 0.80019013]\n [ 0.75489305]\n [ 0.90924849]...
# 361  [[ 0.49715322]\n [ 0.        ]\n [ 0.92368618]...
# 362  [[ 0.43088911]\n [ 0.74425888]\n [ 0.87495001]...
# 363  [[ 0.78829442]\n [ 0.85494635]\n [ 0.8078253 ]...
# 364  [[ 0.39093745]\n [ 0.84744375]\n [ 0.72931786]...
# 365  [[ 0.79567729]\n [ 0.25874318]\n [ 0.69822055]...
# 366  [[ 0.1486033 ]\n [ 0.75446701]\n [ 0.77272055]...
# 367  [[ 0.42186598]\n [ 0.48273413]\n [ 0.78576344]...
# 368  [[ 0.86317517]\n [ 0.66633596]\n [ 0.63174559]...
# 369  [[ 0.93427926]\n [ 0.89974365]\n [ 0.82043889]...
# 370  [[ 0.97867071]\n [ 0.89156089]\n [ 0.52559171]...
# 371  [[ 0.92636255]\n [ 0.        ]\n [ 0.11122829]...
# 372  [[ 0.82710531]\n [ 0.80736026]\n [ 0.60267929]...
# 373  [[ 0.93500837]\n [ 0.94212703]\n [ 0.45797095]...
# 374  [[ 0.82111774]\n [ 0.46934904]\n [ 0.82711364]...
# 375  [[ 0.63500897]\n [ 0.52544984]\n [ 0.8470502 ]...
# 376  [[ 0.60130367]\n [ 0.61996064]\n [ 0.86422378]...
# 377  [[ 0.91223763]\n [ 0.65785091]\n [ 0.        ]...
# 378  [[ 0.61301852]\n [ 0.76023079]\n [ 0.        ]...
# 379  [[ 0.75518036]\n [ 0.71503677]\n [ 0.        ]...
# 380  [[ 0.46496663]\n [ 0.0730557 ]\n [ 0.02256782]...
#
# [381 rows x 7 columns]

# %%
pd.read_csv("suramerica_results_original.csv").drop(['Unnamed: 0'], 1).head()
# Out:
#           Base       Target  Look Back  Reg         %       Time  \
# 0  Agricultura  Agricultura          1   48  0.751710  14.081192
# 1  Agricultura  Agricultura          2   48  0.650503  13.562043
# 2  Agricultura  Agricultura          3   48  0.698588  15.635314
# 3  Agricultura     Ambiente          1   96  0.659490  19.270615
# 4  Agricultura     Ambiente          2   96  0.675724  21.358137
#
#                                              Results
# 0  [[ 0.84417477]\n [ 0.60243841]\n [ 0.49421566]...
# 1  [[ 0.82708981]\n [ 0.46201133]\n [ 0.68394697]...
# 2  [[ 0.62186412]\n [ 0.46657095]\n [ 0.71804695]...
# 3  [[ 0.60493183]\n [ 0.14411922]\n [ 0.54422433]...
# 4  [[ 0.651033  ]\n [ 0.67818193]\n [ 0.69563164]...

# %%
pd.read_csv("suramerica_results_random.csv").drop(['Unnamed: 0'], 1).head()
# Out:
#           Base       Target  Look Back  Reg         %        Time  \
# 0  Agricultura  Agricultura          1   48  0.753705  349.043561
# 1  Agricultura  Agricultura          2   48  0.773581  428.586878
# 2  Agricultura  Agricultura          3   48  0.781177  400.207380
# 3  Agricultura     Ambiente          1   96  0.662694  712.719513
# 4  Agricultura     Ambiente          2   96  0.688307  789.752628
#
#                                              Results
# 0  [[ 0.47820455]\n [ 0.93265366]\n [ 0.12911681]...
# 1  [[ 0.82121739]\n [ 0.91761199]\n [ 0.65325536]...
# 2  [[ 0.80781831]\n [ 0.9232483 ]\n [ 0.69848153]...
# 3  [[ 0.55962093]\n [ 0.57642369]\n [ 0.80735617]...
# 4  [[ 0.64737653]\n [ 0.90532119]\n [ 0.45288735]...

# %%
pd.read_csv("suramerica_results_grid.csv").drop(['Unnamed: 0'], 1).head()
# Out:
#           Base       Target  Look Back  Reg         %        Time  \
# 0  Agricultura  Agricultura          1   48  0.796854  317.614283
# 1  Agricultura  Agricultura          2   48  0.752689  357.953047
# 2  Agricultura  Agricultura          3   48  0.791113  366.047166
# 3  Agricultura     Ambiente          1   96  0.725681  518.815343
# 4  Agricultura     Ambiente          2   96  0.740845  647.211091
#
#                                              Results
# 0  [[ 0.92383091]\n [ 0.91891816]\n [ 0.77532557]...
# 1  [[ 0.6061266 ]\n [ 0.63911117]\n [ 0.96304798]...
# 2  [[ 0.73096749]\n [ 0.94134981]\n [ 0.64646321]...
# 3  [[ 0.84134101]\n [ 0.83863503]\n [ 0.86781816]...
# 4  [[ 0.67773474]\n [ 0.83584079]\n [ 0.42724829]...

# %% [markdown]
# ## Resultados iniciales

# %%
pd.DataFrame.pivot_table(df, index=["Base","Target","Reg"], columns=["Look Back"]).drop(['Time'],1)
# Out:
#                                         %
# Look Back                               1         2         3
# Base        Target          Reg
# Agricultura Agricultura     48   0.796854  0.752689  0.791113
#             Ambiente        96   0.725681  0.740845  0.660708
#             Ayuda           71   0.576212  0.558929  0.544161
#             Ciencia         13   0.900183  0.823847  0.809137
#             Clima           67   0.741598  0.744996  0.742159
#             Comercio        142  0.741123  0.736872  0.755783
#             Deuda           229  0.594924  0.590460  0.594468
#             Economia        258  0.779331  0.757347  0.777363
#             Educacion       168  0.667658  0.677733  0.688597
#             Energia         51   0.783531  0.802873  0.756724
#             Finanzas        67   0.670683  0.674603  0.644984
#             Genero          175  0.610216  0.629433  0.612247
#             Infraestructura 41   0.711455  0.722637  0.693948
#             Pobreza         23   0.650660  0.593671  0.626895
#             Privado         163  0.657950  0.665257  0.671939
#             Publico         97   0.777513  0.822699  0.808895
#             Salud           150  0.575309  0.575432  0.538465
#             Social          35   0.737573  0.656277  0.700369
#             Trabajo         130  0.592267  0.565320  0.565939
#             Urbano          24   0.846948  0.843217  0.856848
# Ambiente    Agricultura     32   0.768281  0.797090  0.790639
#             Ambiente        112  0.677924  0.740249  0.701357
#             Ayuda           71   0.544528  0.550288  0.559225
#             Ciencia         13   0.822557  0.815237  0.836978
#             Clima           31   0.740540  0.834893  0.827596
#             Comercio        144  0.704009  0.712979  0.746055
#             Deuda           229  0.566146  0.569390  0.567331
#             Economia        239  0.738892  0.735726  0.741914
#             Educacion       168  0.645737  0.672522  0.689457
#             Energia         31   0.692214  0.720088  0.732608
# ...                                   ...       ...       ...
# Clima       Social          34   0.697148  0.733214  0.654076
#             Trabajo         133  0.611755  0.607502  0.595777
#             Urbano          16   0.827392  0.808230  0.806183
# Comercio    Agricultura     46   0.737416  0.757279  0.744449
#             Ambiente        112  0.699176  0.654556  0.671174
#             Ayuda           71   0.559728  0.540547  0.517838
#             Ciencia         11   0.924128  0.916800  0.879094
#             Clima           80   0.728657  0.748486  0.713097
#             Comercio        144  0.774692  0.782060  0.788891
#             Deuda           227  0.611545  0.590977  0.605302
#             Economia        228  0.784960  0.774366  0.732012
#             Educacion       168  0.690587  0.646249  0.658680
#             Energia         48   0.704139  0.756871  0.757394
#             Finanzas        67   0.647159  0.680847  0.675683
#             Genero          177  0.600673  0.599683  0.599429
#             Infraestructura 39   0.645327  0.706513  0.721038
#             Pobreza         25   0.598255  0.622667  0.633174
#             Privado         56   0.493356  0.473866  0.505813
#             Publico         93   0.774294  0.811695  0.790122
#             Salud           152  0.570528  0.556866  0.558984
#             Social          35   0.666930  0.667839  0.658631
#             Trabajo         133  0.540595  0.564563  0.564648
#             Urbano          24   0.771297  0.761219  0.743623
# Deuda       Agricultura     48   0.633064  0.713830  0.666532
#             Ambiente        112  0.589236  0.595396  0.606781
#             Ayuda           64   0.496690  0.519129  0.539436
#             Ciencia         13   0.571689  0.749090  0.814192
#             Clima           80   0.639248  0.616638  0.687608
#             Comercio        142  0.659228  0.638625  0.698511
#             Deuda           229  0.646340       NaN       NaN
#
# [127 rows x 3 columns]

# %%
datos = pd.read_csv("suramerica.csv").drop('Unnamed: 0', 1)
paises = datos['CountryCode'].drop_duplicates().values.tolist()
pais_nombre = 'Suramerica'

preprocessing = 'imput'
search = 'grid'
year_init = 2012
year_range = 5
look_back = 3
years = range(year_init-year_range+1,year_init+1)[::-1]

agricultura     = open("Indicadores/iagricultura.txt").read().split(',')
ambiente        = open("Indicadores/iambiente.txt").read().split(',')
ayuda           = open("Indicadores/iayuda.txt").read().split(',')
ciencia         = open("Indicadores/iciencia.txt").read().split(',')
clima           = open("Indicadores/iclima.txt").read().split(',')
comercio        = open("Indicadores/icomercio.txt").read().split(',')
deuda           = open("Indicadores/ideuda.txt").read().split(',')
economia        = open("Indicadores/ieconomia.txt").read().split(',')
educacion       = open("Indicadores/ieducacion.txt").read().split(',')
energia         = open("Indicadores/ienergia.txt").read().split(',')
finanzas        = open("Indicadores/ifinanzas.txt").read().split(',')
genero          = open("Indicadores/igenero.txt").read().split(',')
infraestructura = open("Indicadores/iinfraestructura.txt").read().split(',')
pobreza         = open("Indicadores/ipobreza.txt").read().split(',')
privado         = open("Indicadores/iprivado.txt").read().split(',')
publico         = open("Indicadores/ipublico.txt").read().split(',')
salud           = open("Indicadores/isalud.txt").read().split(',')
social          = open("Indicadores/isocial.txt").read().split(',')
trabajo         = open("Indicadores/itrabajo.txt").read().split(',')
urbano          = open("Indicadores/iurbano.txt").read().split(',')


conjunto_nombre = ['Agricultura','Ambiente','Ayuda','Ciencia','Clima','Comercio','Deuda','Economia','Educacion',
                   'Energia','Finanzas','Genero','Infraestructura','Pobreza','Privado','Publico','Salud','Social',
                   'Trabajo','Urbano']
conjunto = [agricultura,ambiente,ayuda,ciencia,clima,comercio,deuda,economia,educacion,energia,finanzas,genero,
            infraestructura,pobreza,privado,publico,salud,social,trabajo,urbano]

# %%
def tabla_base(indicadores):
    tab = pd.DataFrame.pivot_table(datos, values='Value', index=['CountryCode', 'Year'], columns=['IndicatorCode']).loc[(paises,years),indicadores].sortlevel(["CountryCode","Year"], ascending=[True,False])
    return tab

# %%
def buscar_mejores(df):
    return df[df.Resultados > 0.9].reset_index(drop=True)

# %%
def graficar_resultados(df,look_back):

    trace = go.Heatmap(z=df[df['Look Back'] == look_back]['%'],
                       x=df[df['Look Back'] == look_back]['Base'],
                       y=df[df['Look Back'] == look_back]['Target'],
                       zmax=1.0,
                       zmin=0.0,
                       colorscale = 'Viridis')
    data=[trace]
    
    layout = go.Layout(
        title=pais_nombre+' + '+search+': Total Heatmap with Look Back = '+str(look_back),
        xaxis=dict(title='Base',   titlefont=dict(size=18)),
        yaxis=dict(title='Target', titlefont=dict(size=18))
    )
    
    fig = go.Figure(data=data, layout=layout)

    return py.iplot(fig,filename=pais_nombre+' + '+search+': Total Heatmap with Look Back = '+str(look_back))

# %%
def buscar_resultados(df,indicador_1,indicador_2,look_back):
    #Buscamos Resultados en base al conjunto de indicadores Base, Target y Look Back
    temp = df[(df['Base']==indicador_1)&(df['Target']==indicador_2)&(df['Look Back'] == look_back)]['Results'].values[0]
    df_temp = temp.replace("'","").replace("[","").replace("]","").replace(" ","").split('\n')
    results = []
    for i in df_temp: 
        results.append(float(i))
    
    # Códigos de los indicadores con registros 
    df_nombres = pd.DataFrame(conjunto_nombre, columns=['Resultados'])
    indicador_1 = conjunto[df_nombres[df_nombres['Resultados']==indicador_1].index.values[0]]
    indicador_2 = conjunto[df_nombres[df_nombres['Resultados']==indicador_2].index.values[0]]     
    df = pd.DataFrame(indicador_2)
    
    # Filtro indicadores repetidos
    if(indicador_1!=indicador_2):
        indicador_2 = np.array(df.loc[~df.ix[:,0].isin(indicador_1)]).flatten()
    df_zeros = tabla_base(indicador_2).dropna(how='all',axis=1)
    icodes = df_zeros.columns.values

    # Buscamos Nombres de los Códigos de los Indicadores
    nombres = pd.DataFrame(datos).loc[:,['IndicatorName','IndicatorCode']].set_index('IndicatorCode').loc[icodes].drop_duplicates()

    # Concatenamos Resultados y Nombres, Reindexando en base a los nombres
    df_results = pd.DataFrame(np.column_stack([nombres,results]),columns=['Indicadores','Resultados'])
    
    return df_results

# %%
def graficar_resultados_individuales(df,indicador_base,indicador_target,look_back):

    df_temp = buscar_resultados(df,indicador_base,indicador_target,look_back)

    data = [go.Bar(
                x= df_temp['Indicadores'],
                y= df_temp['Resultados'],

        marker=dict(     
            color = df_temp['Resultados'].values,
            colorscale ='Viridis',
            showscale = True
            ),
        )]

    layout = go.Layout(
        title=pais_nombre+' + '+search+': Result to predict '+indicador_target+' from '+indicador_base+' with '+'Look Back = '+str(look_back),
    )
    
    fig = go.Figure(data=data, layout=layout)

    return py.iplot(fig, filename=pais_nombre+' + '+search+': Result to predict '+indicador_target+' from '+indicador_base+' with '+'Look Back = '+str(look_back))

# %%
def conjuntos_predecibles(df,look_back):
    df_temp = pd.DataFrame.pivot_table( df[df['Look Back'] == 1].drop(['Time','Reg','Results'],1) , index=["Target","Base"], columns=["Look Back"])
    return pd.DataFrame(df_temp[df_temp['%'] > 0.3].count(level=0).sort_values([('%',1)], ascending=False).index.values, columns=["Conjunto"])

# %%
def conjuntos_predictores(df,look_back):
    df_temp = pd.DataFrame.pivot_table( df[df['Look Back'] == 1].drop(['Time','Reg','Results'],1) , index=["Base","Target"], columns=["Look Back"])
    return pd.DataFrame(df_temp[df_temp['%'] > 0.3].count(level=0).sort_values([('%',1)], ascending=False).index.values, columns=["Conjunto"])

# %% [markdown]
# ## Buscamos Mejores Resultados Individuales

# %%
buscar_mejores(buscar_resultados(df,'Agricultura','Infraestructura',1))
# Out:
#                                           Indicadores Resultados
# 0             Air transport, freight (million ton-km)   0.904512
# 1                   Air transport, passengers carried   0.950756
# 2   Air transport, registered carrier departures w...   0.918167
# 3         Electric power consumption (kWh per capita)    0.98148
# 4   Electric power transmission and distribution l...   0.913543
# 5   Electricity production from coal sources (% of...   0.946479
# 6   Electricity production from hydroelectric sour...   0.943024
# 7   Electricity production from natural gas source...   0.984519
# 8   Electricity production from nuclear sources (%...    0.99886
# 9   Electricity production from oil sources (% of ...   0.905818
# 10                      Fixed broadband subscriptions   0.954686
# 11     Fixed broadband subscriptions (per 100 people)   0.955238
# 12     Fixed telephone subscriptions (per 100 people)   0.908414
# 13          ICT goods imports (% total goods imports)   0.932546
# 14             ICT service exports (BoP, current US$)    0.90437
# 15  Improved water source (% of population with ac...   0.981501
# 16  Improved water source, urban (% of urban popul...   0.947826
# 17  Investment in transport with private participa...   0.920511
# 18                      Mobile cellular subscriptions   0.910376
# 19                        Rail lines (total route-km)   0.965386
# 20       Railways, goods transported (million ton-km)   0.961155
# 21  Railways, passengers carried (million passenge...    0.99702

# %% [markdown]
# ## Mejores combinaciones

# %%
df.sort_values('%', ascending=False).reset_index().drop(['index','Time','Results'],1)[:10]
# Out:
#           Base   Target  Look Back  Reg         %
# 0     Comercio  Ciencia          1   11  0.924128
# 1     Comercio  Ciencia          2   11  0.916800
# 2      Ciencia  Ciencia          2   13  0.906317
# 3  Agricultura  Ciencia          1   13  0.900183
# 4        Clima  Ciencia          1   13  0.891478
# 5      Ciencia  Ciencia          3   13  0.889735
# 6     Comercio  Ciencia          3   11  0.879094
# 7     Ambiente   Urbano          2   17  0.861583
# 8  Agricultura   Urbano          3   24  0.856848
# 9  Agricultura   Urbano          1   24  0.846948

# %% [markdown]
# ## Peores combinaciones

# %%
df.sort_values('%', ascending=False).reset_index().drop(['index','Time','Results'],1).tail(10)
# Out:
#         Base   Target  Look Back  Reg         %
# 371  Ciencia   Genero          2  177  0.447552
# 372  Ciencia    Salud          2  152  0.444787
# 373  Ciencia  Trabajo          2  133  0.431418
# 374  Ciencia    Ayuda          3   71  0.421815
# 375  Ciencia    Salud          1  152  0.391678
# 376  Ciencia   Genero          1  177  0.370734
# 377  Ciencia  Pobreza          1   25  0.369564
# 378  Ciencia  Trabajo          1  133  0.366290
# 379  Ciencia    Ayuda          1   71  0.352208
# 380  Ciencia    Ayuda          2   71  0.344247

# %% [markdown]
# ## Graficamos Resultados Individuales

# %% [markdown]
# Resultado de predecir el conjunto de indicadores de Infraestructura desde Agricultura

# %%
graficar_resultados_individuales(df,'Agricultura','Infraestructura',1)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ambigus9/230.embed" height="525px" width="100%"></iframe>

# %%
graficar_resultados_individuales(df,'Agricultura','Economia',1)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ambigus9/234.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Graficamos Resultados Globales

# %% [markdown]
# Este Heatmap nos muestra el porcentaje de cada conjunto indicadores que tiene un Score de R2 > 90% (0.9)

# %%
graficar_resultados(df,1)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ambigus9/238.embed" height="525px" width="100%"></iframe>

# %%
graficar_resultados(df,2)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ambigus9/242.embed" height="525px" width="100%"></iframe>

# %%
graficar_resultados(df,3)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ambigus9/244.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Conclusiones

# %% [markdown]
# - Con el objetivo de encontrar los conjuntos con mayor grado de predictibilidad, contamos la cantidad de conjuntos en los cuales el 30% o más de sus indicadores obtuvieron un puntaje mayor al 90% para dos casos:
#
#  **Predictor:** Conjunto que predice a otro conjunto
#
#  **Predecible:** Conjunto que es predecido por otro conjunto

# %%
pd.DataFrame(np.column_stack([conjuntos_predictores(df,1)[:5],conjuntos_predictores(df,1).tail(5),conjuntos_predecibles(df,1)[:5],conjuntos_predecibles(df,1).tail(5)]), columns=['Best Predictor','Worse Predictor','Easier Predictable','Hard Predictable'])
# Out:
#   Best Predictor Worse Predictor Easier Predictable Hard Predictable
# 0    Agricultura           Ayuda        Agricultura           Genero
# 1       Ambiente         Ciencia              Ayuda          Energia
# 2          Ayuda           Clima            Ciencia        Educacion
# 3        Ciencia        Comercio              Clima         Economia
# 4          Clima           Deuda           Comercio           Urbano
