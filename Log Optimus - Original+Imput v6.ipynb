# %%
import pandas as pd
df = pd.read_csv("log_base.csv").drop(['Unnamed: 0'], 1)
df
# Out:
#            Base       Target  Look Back  Reg         %       Time  \
# 0   Agricultura  Agricultura          1   48  0.431818  11.688473
# 1   Agricultura  Agricultura          2   48  0.431818  13.257339
# 2   Agricultura  Agricultura          3   48  0.340909  15.410448
# 3   Agricultura     Ambiente          1   96  0.333333  19.309750
# 4   Agricultura     Ambiente          2   96  0.320000  20.159568
# 5   Agricultura     Ambiente          3   96  0.333333  21.970068
# 6   Agricultura        Ayuda          1   71  0.151515  19.931785
# 7   Agricultura        Ayuda          2   71  0.166667  21.595775
# 8   Agricultura        Ayuda          3   71  0.075758  24.577634
# 9   Agricultura      Ciencia          1   13  0.307692   5.591951
# 10  Agricultura      Ciencia          2   13  0.461538   5.839250
# 11  Agricultura      Ciencia          3   13  0.153846   8.407159
# 12  Agricultura        Clima          1   67  0.563636  11.326454
# 13  Agricultura        Clima          2   67  0.472727  15.533488
# 14  Agricultura        Clima          3   67  0.436364  16.808518
# 15  Agricultura     Comercio          1  142  0.262411  37.820030
# 16  Agricultura     Comercio          2  142  0.234043  42.085050
# 17  Agricultura     Comercio          3  142  0.234043  39.944651
#
#                                               Results
# 0   [[ 0.68753774]\n [ 0.90037844]\n [ 0.61447808]...
# 1   [[ 0.17453267]\n [ 0.66077826]\n [ 0.39168816]...
# 2   [[ 0.29187166]\n [ 0.58819009]\n [ 0.69600618]...
# 3   [[ 0.53920055]\n [ 0.89761976]\n [ 0.39338693]...
# 4   [[ 0.90145709]\n [ 0.92784975]\n [ 0.77038856]...
# 5   [[ 0.63517259]\n [ 0.4890869 ]\n [ 0.73448915]...
# 6   [[ 1.        ]\n [ 0.5290692 ]\n [ 0.79700381]...
# 7   [[ 1.        ]\n [ 0.86643875]\n [ 0.18328508]...
# 8   [[ 1.        ]\n [ 0.81686976]\n [ 0.44011456]...
# 9   [[ 0.75763265]\n [ 0.68413181]\n [ 0.        ]...
# 10  [[ 0.87141239]\n [ 0.43310938]\n [ 0.36087605]...
# 11  [[ 0.6434818 ]\n [ 0.99175799]\n [ 0.45547605]...
# 12  [[ 0.39274333]\n [ 0.        ]\n [ 0.45574605]...
# 13  [[ 0.31226508]\n [ 0.        ]\n [ 0.        ]...
# 14  [[ 0.50322088]\n [ 0.        ]\n [ 0.6400408 ]...
# 15  [[ 0.02626634]\n [ 0.65347251]\n [ 0.22680361]...
# 16  [[ 0.45835302]\n [ 0.43148056]\n [ 0.15123624]...
# 17  [[ 0.        ]\n [ 0.29673006]\n [ 0.        ]...

# %%
pd.DataFrame.pivot_table(df, index=["Base","Target","Reg"], columns=["Look Back"]).drop(['Time'],1)
# Out:
#                                     %
# Look Back                           1         2         3
# Base        Target      Reg
# Agricultura Agricultura 48   0.431818  0.431818  0.340909
#             Ambiente    96   0.333333  0.320000  0.333333
#             Ayuda       71   0.151515  0.166667  0.075758
#             Ciencia     13   0.307692  0.461538  0.153846
#             Clima       67   0.563636  0.472727  0.436364
#             Comercio    142  0.262411  0.234043  0.234043

# %%
def graficar(df,look_back):
    import seaborn as sns
    import matplotlib.pyplot as plt
    df_temp = df[df['Look Back'] == 1].drop(['Time','Reg','Look Back','Results'], 1)
    df_temp = pd.DataFrame(np.array(pd.DataFrame.pivot_table(df_temp, index=["Base"], columns=["Target"])), index=[conjunto_nombre], columns=[conjunto_nombre])
    ax = sns.heatmap(df_temp)
    plt.title('Look back = '+str(look_back), size=15)
    return plt.show()

# %%
import numpy as np
conjunto_nombre = ['Agricultura','Economia','Educacion','Salud','Deuda']
df_temp = df[df['Look Back'] == 1].drop(['Time','Reg','Look Back','Results'], 1)
df_temp = pd.DataFrame(np.array(pd.DataFrame.pivot_table(df_temp, index=["Base"], columns=["Target"])), index=[conjunto_nombre], columns=[conjunto_nombre])
# Out:
#              Agricultura  Economia  Educacion     Salud     Deuda
# Agricultura     0.454545  0.290179   0.444000  0.275862  0.336000
# Economia        0.204545  0.178571   0.323144  0.129310  0.110236
# Educacion       0.238095  0.194030   0.464286  0.103448  0.188976
# Salud           0.204545  0.183036   0.253968  0.094828  0.152000
# Deuda           0.452381  0.232143   0.412698  0.289474  0.448819

# %%
graficar(df,1)
