# %% [markdown]
# ## Colombia World Development Indicators Analytics

# %%
import pandas as pd
import numpy as np
import plotly.plotly as py
import plotly.graph_objs as go

datos = pd.read_csv("suramerica.csv").drop('Unnamed: 0', 1)
paises = ['COL']
pais_nombre = 'Colombia'

preprocessing = 'imput'
search = 'original'
year_init = 2015
year_range = 15
look_back = 3
years = range(year_init-year_range+1,year_init+1)[::-1]

agricultura     = open("Indicadores/iagricultura.txt").read().split(',')
ambiente        = open("Indicadores/iambiente.txt").read().split(',')
ayuda           = open("Indicadores/iayuda.txt").read().split(',')
ciencia         = open("Indicadores/iciencia.txt").read().split(',')
clima           = open("Indicadores/iclima.txt").read().split(',')
comercio        = open("Indicadores/icomercio.txt").read().split(',')
deuda           = open("Indicadores/ideuda.txt").read().split(',')
economia        = open("Indicadores/ieconomia.txt").read().split(',')
educacion       = open("Indicadores/ieducacion.txt").read().split(',')
energia         = open("Indicadores/ienergia.txt").read().split(',')
finanzas        = open("Indicadores/ifinanzas.txt").read().split(',')
genero          = open("Indicadores/igenero.txt").read().split(',')
infraestructura = open("Indicadores/iinfraestructura.txt").read().split(',')
pobreza         = open("Indicadores/ipobreza.txt").read().split(',')
privado         = open("Indicadores/iprivado.txt").read().split(',')
publico         = open("Indicadores/ipublico.txt").read().split(',')
salud           = open("Indicadores/isalud.txt").read().split(',')
social          = open("Indicadores/isocial.txt").read().split(',')
trabajo         = open("Indicadores/itrabajo.txt").read().split(',')
urbano          = open("Indicadores/iurbano.txt").read().split(',')

conjunto_nombre = ['Agricultura','Ambiente','Ayuda','Ciencia','Clima','Comercio','Deuda','Economia','Educacion',
                   'Energia','Finanzas','Genero','Infraestructura','Pobreza','Privado','Publico','Salud','Social',
                   'Trabajo','Urbano']

conjunto = [agricultura,ambiente,ayuda,ciencia,clima,comercio,deuda,economia,educacion,energia,finanzas,genero,
            infraestructura,pobreza,privado,publico,salud,social,trabajo,urbano]

datos.head()
# Out:
#            CountryName CountryCode  \
# 0  Antigua and Barbuda         ATG
# 1  Antigua and Barbuda         ATG
# 2  Antigua and Barbuda         ATG
# 3  Antigua and Barbuda         ATG
# 4  Antigua and Barbuda         ATG
#
#                                        IndicatorName   IndicatorCode  Year  \
# 0  Adolescent fertility rate (births per 1,000 wo...     SP.ADO.TFRT  1960
# 1  Age dependency ratio (% of working-age populat...     SP.POP.DPND  1960
# 2  Age dependency ratio, old (% of working-age po...  SP.POP.DPND.OL  1960
# 3  Age dependency ratio, young (% of working-age ...  SP.POP.DPND.YG  1960
# 4               Birth rate, crude (per 1,000 people)  SP.DYN.CBRT.IN  1960
#
#         Value
# 0  126.144000
# 1   88.237117
# 2    7.779958
# 3   80.457159
# 4   32.920000

# %% [markdown]
# ## Promedio de Rendimiento

# %%
resultados = pd.read_csv("colombia_original_log.csv").drop('Unnamed: 0', 1)

pd.DataFrame((resultados[resultados['Look Back']==2]['%'].values/resultados[resultados['Look Back']==1]['%'].values)-1)*100
# Out:
#              0
# 0    -8.879261
# 1    -6.562222
# 2     0.623730
# 3    22.458666
# 4   -21.358855
# 5    -3.336695
# 6    -4.696976
# 7    20.424620
# 8    -8.172113
# 9   -17.416736
# 10   -5.567910
# 11   38.410483
# 12   14.468321
# 13    2.957920
# 14   15.716867
# 15   18.909181
# 16   19.063342
# 17  -27.270284
# 18    0.439702
# 19   -5.214146
# 20   -6.763751
# 21   -7.503621
# 22    8.447391
# 23  -12.287837
# 24   12.214899
# 25   11.206278
# 26   -0.854631
# 27  -12.991445
# 28    5.694767
# 29  -10.092828
# ..         ...
# 370 -13.205323
# 371  10.135520
# 372  23.276837
# 373  28.850364
# 374   0.336111
# 375 -14.635955
# 376 -14.075391
# 377  37.246394
# 378 -15.098640
# 379  48.674141
# 380   4.029347
# 381   3.149784
# 382 -19.773009
# 383  10.736855
# 384  -4.459070
# 385   5.161706
# 386  -9.533887
# 387  -4.140513
# 388  18.690505
# 389   0.916703
# 390  -4.192392
# 391   8.389614
# 392 -18.596103
# 393 -32.300922
# 394   7.416134
# 395   5.250434
# 396  -3.413177
# 397  13.880595
# 398 -11.096932
# 399 -13.858165
#
# [400 rows x 1 columns]

# %%
df = resultados
df[df['Look Back']==1].groupby('Base').mean().sort_values('%', ascending=False).index.values[:5]
# Out:
# array(['Salud', 'Urbano', 'Economia', 'Clima', 'Ciencia'], dtype=object)

# %%
df_mean
# Out:
#                  Look Back     Reg         %       Time
# Base
# Salud                  1.0  101.15  0.433663  21.983977
# Urbano                 1.0  103.50  0.431319  21.971159
# Economia               1.0   98.85  0.414579  22.400105
# Clima                  1.0   98.80  0.409295  22.340288
# Ciencia                1.0  104.50  0.398558  23.173375
# Privado                1.0   97.60  0.395674  21.403402
# Social                 1.0  101.65  0.394699  21.635336
# Agricultura            1.0  102.40  0.376734  22.565217
# Finanzas               1.0  102.90  0.374121  22.994043
# Infraestructura        1.0  102.60  0.368476  22.422080
# Comercio               1.0   96.80  0.365133  21.371000
# Genero                 1.0   94.15  0.356069  21.640545
# Ayuda                  1.0  103.05  0.349771  23.604380
# Energia                1.0  101.30  0.348686  23.633265
# Ambiente               1.0   98.65  0.348354  22.617108
# Trabajo                1.0   99.95  0.338418  22.107255
# Educacion              1.0   99.35  0.337528  23.166245
# Publico                1.0  103.50  0.332638  22.731269
# Deuda                  1.0  102.65  0.315579  23.609363
# Pobreza                1.0  104.35  0.278601  23.336985

# %%
df = resultados
df_temp = pd.DataFrame.pivot_table( df[df['Look Back'] == 1].drop(['Time','Reg','Results'],1) , index=["Base","Target"], columns=["Look Back"])
np.mean(df_temp.values[20:40])
# Out:
# 0.34835393028080003

# %%
def conjuntos_performance(df,look_back,perform,predict,rango):
    return df[df['Look Back']==look_back].groupby(predict).mean().sort_values('%', ascending=perform).index.values[:rango]

# %%
def predecibles_predictores(df,look_back,rango):
    return pd.DataFrame(np.column_stack([conjuntos_performance(df,look_back,False,'Base',rango),conjuntos_performance(df,look_back,True,'Base',rango),conjuntos_performance(df,look_back,False,'Target',rango),conjuntos_performance(df,look_back,True,'Target',rango)]),columns=[['Predictor','Predictor','Predictable','Predictable'],['Best','Worse','Easy','Hard']])

# %%
predecibles_predictores(resultados,1,5)
# Out:
#   Predictor             Predictable
#        Best      Worse         Easy       Hard
# 0     Salud    Pobreza        Salud    Publico
# 1    Urbano      Deuda       Urbano    Pobreza
# 2  Economia    Publico     Economia  Educacion
# 3     Clima  Educacion  Agricultura     Genero
# 4   Ciencia    Trabajo      Privado    Energia

# %% [markdown]
# ## Categorizamos los Indicadores

# %% [markdown]
# Categorizamos los Indicadores en sus respectivos conjuntos

# %%
def categorizar_indicadores(df):
    for i in range(len(conjunto)):
        df.loc[df['IndicatorCode'].isin(conjunto[i]), 'Set'] = conjunto_nombre[i]
    return df

# %%
df = categorizar_indicadores(datos)
df.head()
# Out:
#            CountryName CountryCode  \
# 0  Antigua and Barbuda         ATG
# 1  Antigua and Barbuda         ATG
# 2  Antigua and Barbuda         ATG
# 3  Antigua and Barbuda         ATG
# 4  Antigua and Barbuda         ATG
#
#                                        IndicatorName   IndicatorCode  Year  \
# 0  Adolescent fertility rate (births per 1,000 wo...     SP.ADO.TFRT  1960
# 1  Age dependency ratio (% of working-age populat...     SP.POP.DPND  1960
# 2  Age dependency ratio, old (% of working-age po...  SP.POP.DPND.OL  1960
# 3  Age dependency ratio, young (% of working-age ...  SP.POP.DPND.YG  1960
# 4               Birth rate, crude (per 1,000 people)  SP.DYN.CBRT.IN  1960
#
#         Value     Set
# 0  126.144000  Social
# 1   88.237117   Salud
# 2    7.779958   Salud
# 3   80.457159   Salud
# 4   32.920000   Salud

# %% [markdown]
# ## Graficamos Registros Paises

# %% [markdown]
# Graficamos la cantidad de años registrados para cada uno de los paises de Suramérica

# %%
def registros_country_year(df):
    return df.groupby(['CountryName','Year']).agg(['count']).drop(['CountryCode','IndicatorName','IndicatorCode','Set'], 1)

# %%
def graficar_registros_paises(df):

    trace = go.Heatmap(z=df.reset_index(col_level=0)['Value'].values,
                       x=df.reset_index(col_level=0)['Year'],
                       y=df.reset_index(col_level=0)['CountryName'],
                       colorscale = 'Viridis')
    data=[trace]
    
    layout = go.Layout(
        title='Registros Pais + Años',
        xaxis=dict(title='Años',   titlefont=dict(size=18)),
        yaxis=dict(title='Paises', titlefont=dict(size=18))
    )
    
    fig = go.Figure(data=data, layout=layout)

    return py.iplot(fig,filename='Registros por Años')

# %%
graficar_registros_paises(registros_country_year(df))
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-8-2e3ba0caa901> in <module>()
# ----> 1 graficar_registros_paises(registros_country_year(df))
#
# <ipython-input-7-79b6b85658bf> in graficar_registros_paises(df)
#      15     fig = go.Figure(data=data, layout=layout)
#      16
# ---> 17     return py.iplot(fig,filename='Registros por Años')
#
# /home/familia-plazas/anaconda2/lib/python2.7/site-packages/plotly/plotly/plotly.pyc in iplot(figure_or_data, **plot_options)
#     132     if 'auto_open' not in plot_options:
#     133         plot_options['auto_open'] = False
# --> 134     url = plot(figure_or_data, **plot_options)
#     135
#     136     if isinstance(figure_or_data, dict):
#
# /home/familia-plazas/anaconda2/lib/python2.7/site-packages/plotly/plotly/plotly.pyc in plot(figure_or_data, validate, **plot_options)
#     225     data = fig.get('data', [])
#     226     plot_options['layout'] = fig.get('layout', {})
# --> 227     response = v1.clientresp(data, **plot_options)
#     228
#     229     # Check if the url needs a secret key
#
# /home/familia-plazas/anaconda2/lib/python2.7/site-packages/plotly/api/v1/clientresp.pyc in clientresp(data, **kwargs)
#      33
#      34     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 35     response = request('post', url, data=payload)
#      36
#      37     # Old functionality, just keeping it around.
#
# /home/familia-plazas/anaconda2/lib/python2.7/site-packages/plotly/api/v1/utils.pyc in request(method, url, **kwargs)
#      84         content = response.content if response else 'No content'
#      85         raise exceptions.PlotlyRequestError(message, status_code, content)
# ---> 86     validate_response(response)
#      87     return response
#
# /home/familia-plazas/anaconda2/lib/python2.7/site-packages/plotly/api/v1/utils.pyc in validate_response(response)
#      36         message = content if content else 'No Content'
#      37
# ---> 38     raise exceptions.PlotlyRequestError(message, status_code, content)
#      39
#      40
#
# PlotlyRequestError: Hey there! You've hit one of our API request limits.
#
# To get unlimited API calls(10,000/day), please upgrade to a paid plan.
#
# UPGRADE HERE: https://goo.gl/i7glmM
#
# Thanks for using Plotly! Happy Plotting!

# %% [markdown]
# ## Graficamos Registros Conjuntos

# %% [markdown]
# Graficamos los registros de años para cada conjunto de indicadores para Colombia

# %%
def registros_set_year(df,pais):
    return df[df['CountryCode'] == pais].groupby(['Set','Year']).agg(['count']).drop(['CountryName','CountryCode','IndicatorName','IndicatorCode'], 1)

# %%
def graficar_registros_conjuntos(df,pais):

    trace = go.Heatmap(z=df.reset_index(col_level=0)['Value'].values,
                       x=df.reset_index(col_level=0)['Year'],
                       y=df.reset_index(col_level=0)['Set'],
                       colorscale = 'Viridis')
    data=[trace]
    
    layout = go.Layout(
        title='Registros Conjunto + Años para '+pais,
        xaxis=dict(title='Paises',   titlefont=dict(size=18)),
        yaxis=dict(title='Años', titlefont=dict(size=18))
    )
    
    fig = go.Figure(data=data, layout=layout)

    return py.iplot(fig,filename='Registros Conjunto + Años para '+pais)

# %%
graficar_registros_conjuntos(registros_set_year(df,'COL'),'Colombia')

# %% [markdown]
# ## Cargamos Resultados para Colombia y parámetros Originales

# %% [markdown]
# Si eliminamos los indicadores con menos de 5 registros y ampliamos el espectro de años a 15 e iniciamos desde 2015 hacia atrás. Tendremos los siguientes resultados:

# %%
resultados = pd.read_csv("colombia_original_log.csv").drop('Unnamed: 0', 1)
resultados
# Out:
#              Base           Target  Look Back  Reg         %       Time  \
# 0     Agricultura      Agricultura          1   48  0.455277  10.584898
# 1     Agricultura      Agricultura          2   48  0.414852  13.457072
# 2     Agricultura      Agricultura          3   48  0.394925  13.106958
# 3     Agricultura         Ambiente          1   96  0.307334  16.575595
# 4     Agricultura         Ambiente          2   96  0.287166  18.022063
# 5     Agricultura         Ambiente          3   96  0.286223  18.956299
# 6     Agricultura            Ayuda          1   71  0.382280  17.504265
# 7     Agricultura            Ayuda          2   71  0.384664  18.287500
# 8     Agricultura            Ayuda          3   71  0.420092  19.652280
# 9     Agricultura          Ciencia          1   13  0.429908   5.675936
# 10    Agricultura          Ciencia          2   13  0.526460   6.966463
# 11    Agricultura          Ciencia          3   13  0.359109   8.054454
# 12    Agricultura            Clima          1   67  0.404357  12.573218
# 13    Agricultura            Clima          2   67  0.317991  15.026738
# 14    Agricultura            Clima          3   67  0.303738  16.695707
# 15    Agricultura         Comercio          1  142  0.385315  36.118337
# 16    Agricultura         Comercio          2  142  0.372458  37.032504
# 17    Agricultura         Comercio          3  142  0.408497  37.551263
# 18    Agricultura            Deuda          1  229  0.399775  58.190400
# 19    Agricultura            Deuda          2  229  0.380998  59.279684
# 20    Agricultura            Deuda          3  229  0.392082  59.631616
# 21    Agricultura         Economia          1  258  0.391107  68.414853
# 22    Agricultura         Economia          2  258  0.470989  69.198278
# 23    Agricultura         Economia          3  258  0.424218  72.710434
# 24    Agricultura        Educacion          1  168  0.332868  32.773233
# 25    Agricultura        Educacion          2  168  0.305666  34.068100
# 26    Agricultura        Educacion          3  168  0.288547  36.535992
# 27    Agricultura          Energia          1   51  0.378089  12.634916
# 28    Agricultura          Energia          2   51  0.312238  14.092758
# 29    Agricultura          Energia          3   51  0.326550  15.579574
# ...           ...              ...        ...  ...       ...        ...
# 1170       Urbano         Finanzas          1   67  0.404308  17.077399
# 1171       Urbano         Finanzas          2   67  0.387358  18.406805
# 1172       Urbano         Finanzas          3   67  0.440543  20.077385
# 1173       Urbano           Genero          1  177  0.333585  30.714756
# 1174       Urbano           Genero          2  177  0.361572  33.110508
# 1175       Urbano           Genero          3  177  0.352030  32.036810
# 1176       Urbano  Infraestructura          1   42  0.479024  10.211755
# 1177       Urbano  Infraestructura          2   42  0.389944  12.158855
# 1178       Urbano  Infraestructura          3   42  0.427210  12.540909
# 1179       Urbano          Pobreza          1   22  0.383994   6.848615
# 1180       Urbano          Pobreza          2   22  0.259960   7.930539
# 1181       Urbano          Pobreza          3   22  0.288541   8.679558
# 1182       Urbano          Privado          1  165  0.481318  30.097158
# 1183       Urbano          Privado          2  165  0.517013  34.693261
# 1184       Urbano          Privado          3  165  0.412960  33.616778
# 1185       Urbano          Publico          1   97  0.179014  17.343178
# 1186       Urbano          Publico          2   97  0.188413  18.381524
# 1187       Urbano          Publico          3   97  0.183076  18.841018
# 1188       Urbano            Salud          1  149  0.645482  18.278908
# 1189       Urbano            Salud          2  149  0.623450  19.969232
# 1190       Urbano            Salud          3  149  0.619510  21.248627
# 1191       Urbano           Social          1   35  0.514450   8.132997
# 1192       Urbano           Social          2   35  0.585859   9.744151
# 1193       Urbano           Social          3   35  0.478110  10.718298
# 1194       Urbano          Trabajo          1  133  0.406413  28.452537
# 1195       Urbano          Trabajo          2  133  0.361313  28.539003
# 1196       Urbano          Trabajo          3  133  0.395997  30.223503
# 1197       Urbano           Urbano          1   24  0.669267   5.653761
# 1198       Urbano           Urbano          2   24  0.576519   6.143457
# 1199       Urbano           Urbano          3   24  0.520378   8.061021
#
#                                                 Results
# 0     [[ 0.        ]\n [ 0.        ]\n [ 0.93549912]...
# 1     [[ 0.        ]\n [ 0.        ]\n [ 0.81843835]...
# 2     [[ 0.32661843]\n [ 0.60803299]\n [ 0.50717803]...
# 3     [[ 0.        ]\n [ 0.74249732]\n [ 0.        ]...
# 4     [[ 0.        ]\n [ 0.85310254]\n [ 0.        ]...
# 5     [[ 0.16877031]\n [ 0.        ]\n [ 0.        ]...
# 6     [[ 1.        ]\n [ 0.29062546]\n [ 1.        ]...
# 7     [[ 1.        ]\n [ 0.88768056]\n [ 1.        ]...
# 8     [[ 1.        ]\n [ 0.83451842]\n [ 1.        ]...
# 9     [[ 0.40123109]\n [ 0.        ]\n [ 0.75798151]...
# 10    [[ 0.68452153]\n [ 0.88615762]\n [ 0.00254929]...
# 11    [[ 0.53968864]\n [ 0.71894124]\n [ 0.74365687]...
# 12    [[ 0.        ]\n [ 0.70268907]\n [ 0.63606519]...
# 13    [[ 0.        ]\n [ 0.        ]\n [ 0.87887107]...
# 14    [[ 0.36589416]\n [ 0.64791907]\n [ 0.        ]...
# 15    [[ 0.        ]\n [ 1.        ]\n [ 1.        ]...
# 16    [[ 0.        ]\n [ 1.        ]\n [ 1.        ]...
# 17    [[ 0.43945927]\n [ 1.        ]\n [ 1.        ]...
# 18    [[ 0.        ]\n [ 0.16023494]\n [ 0.        ]...
# 19    [[ 0.        ]\n [ 0.        ]\n [ 0.        ]...
# 20    [[ 0.        ]\n [ 0.21054931]\n [ 0.        ]...
# 21    [[ 0.        ]\n [ 0.        ]\n [ 0.79617266]...
# 22    [[ 0.        ]\n [ 0.        ]\n [ 0.9956917 ]...
# 23    [[ 0.37328958]\n [ 0.53515686]\n [ 0.64018881]...
# 24    [[ 0.12820348]\n [ 0.        ]\n [ 0.35054676]...
# 25    [[ 0.50557905]\n [ 0.        ]\n [ 0.        ]...
# 26    [[ 0.        ]\n [ 0.        ]\n [ 0.44895788]...
# 27    [[ 0.        ]\n [ 0.6124027 ]\n [ 0.        ]...
# 28    [[ 0.        ]\n [ 0.27805315]\n [ 0.53927483]...
# 29    [[ 0.32629595]\n [ 0.95599462]\n [ 0.        ]...
# ...                                                 ...
# 1170  [[ 0.28684851]\n [ 0.        ]\n [ 0.26257077]...
# 1171  [[ 0.        ]\n [ 0.38897055]\n [ 0.        ]...
# 1172  [[ 0.36406091]\n [ 0.98664174]\n [ 0.30453651]...
# 1173  [[ 0.        ]\n [ 0.        ]\n [ 0.98102152]...
# 1174  [[ 0.31112843]\n [ 0.49788384]\n [ 0.87983791]...
# 1175  [[ 0.00651215]\n [ 0.        ]\n [ 0.94214979]...
# 1176  [[ 0.75101494]\n [ 0.        ]\n [ 0.74626685]...
# 1177  [[  3.44515533e-01]\n [  5.42062411e-01]\n [  ...
# 1178  [[ 0.66871716]\n [ 0.        ]\n [ 0.33932606]...
# 1179  [[ 0.        ]\n [ 0.29697291]\n [ 0.        ]...
# 1180  [[ 0.58685054]\n [ 0.46282143]\n [ 0.3357779 ]...
# 1181  [[ 0.26371056]\n [ 0.        ]\n [ 0.        ]...
# 1182  [[ 0.48137052]\n [ 0.93860817]\n [ 1.        ]...
# 1183  [[ 0.        ]\n [ 0.97145754]\n [ 1.        ]...
# 1184  [[ 0.97370564]\n [ 0.80568259]\n [ 1.        ]...
# 1185  [[  7.57608073e-02]\n [  9.11243486e-01]\n [  ...
# 1186  [[ 0.31373435]\n [ 0.92919117]\n [ 0.        ]...
# 1187  [[ 0.27177398]\n [ 0.91594362]\n [ 0.6819051 ]...
# 1188  [[ 0.87145355]\n [ 0.77893707]\n [ 0.95614962]...
# 1189  [[ 0.94081369]\n [ 0.90911485]\n [ 0.92051625]...
# 1190  [[ 0.97436275]\n [ 0.96468561]\n [ 0.88032626]...
# 1191  [[ 0.78375172]\n [ 0.        ]\n [ 0.9983829 ]...
# 1192  [[ 0.97028559]\n [ 0.7535213 ]\n [ 0.99304839]...
# 1193  [[ 0.31878179]\n [ 0.90752784]\n [ 0.84836465]...
# 1194  [[ 0.73259146]\n [ 0.50000018]\n [ 0.80461548]...
# 1195  [[ 0.        ]\n [ 0.        ]\n [ 0.15732555]...
# 1196  [[ 0.52952032]\n [ 0.        ]\n [ 0.47999382]...
# 1197  [[ 0.78398256]\n [ 1.        ]\n [ 0.72721594]...
# 1198  [[ 0.87134921]\n [ 0.51536026]\n [ 0.92496248]...
# 1199  [[ 0.02384615]\n [ 0.445     ]\n [ 0.43446874]...
#
# [1200 rows x 7 columns]

# %% [markdown]
# ## Mejores Combinaciones

# %%
resultados.sort_values('%', ascending=False).reset_index().drop(['index','Time','Results'],1)[:10]
# Out:
#        Base  Target  Look Back  Reg         %
# 0    Social  Urbano          2   24  0.721845
# 1    Social  Urbano          3   24  0.693165
# 2    Urbano  Urbano          1   24  0.669267
# 3   Energia  Urbano          2   20  0.661917
# 4    Urbano   Salud          1  149  0.645482
# 5     Clima  Urbano          2   16  0.643453
# 6    Social   Salud          2  145  0.641142
# 7     Salud  Urbano          2   21  0.639400
# 8     Salud   Salud          1  152  0.637943
# 9  Economia  Urbano          2   24  0.637235

# %% [markdown]
# ## Peores Combinaciones

# %%
resultados.sort_values('%', ascending=True).reset_index().drop(['index','Time','Results'],1)[:10]
# Out:
#               Base   Target  Look Back  Reg         %
#             Finanzas        67   18.406805  20.077385
#             Genero          177  33.110508  32.036810
#             Infraestructura 42   12.158855  12.540909
#             Pobreza         22    7.930539   8.679558
#             Privado         165  34.693261  33.616778
#             Publico         97   18.381524  18.841018
#             Salud           149  19.969232  21.248627
#             Social          35    9.744151  10.718298
#             Trabajo         133  28.539003  30.223503
#             Urbano          24    6.143457   8.061021
#
# [400 rows x 6 columns]

# %% [markdown]
# ## Rendimiento Look Back

# %%
resultados[resultados['Look Back']==1]

# %% [markdown]
# ## Graficamos Resultados Globales
#
# El siguiente Heatmap nos muestra el promedio del Score R2 obtenido para cada conjunto de indicadores

# %%
def graficar_resultados(df,look_back):

    trace = go.Heatmap(z=df[df['Look Back'] == look_back]['%'],
                       x=df[df['Look Back'] == look_back]['Base'],
                       y=df[df['Look Back'] == look_back]['Target'],
                       zmax=1.0,
                       zmin=0.0,
                       colorscale = 'Viridis')
    data=[trace]
    
    layout = go.Layout(
        title=pais_nombre+' + '+search+': Total Heatmap with Look Back = '+str(look_back),
        xaxis=dict(title='Base',   titlefont=dict(size=18)),
        yaxis=dict(title='Target', titlefont=dict(size=18))
    )
    
    fig = go.Figure(data=data, layout=layout)

    return py.iplot(fig,filename=pais_nombre+' + '+search+': Total Heatmap with Look Back = '+str(look_back))

# %%
graficar_resultados(resultados,1)

# %%
graficar_resultados(resultados,2)

# %%
graficar_resultados(resultados,3)

# %% [markdown]
# ## Conclusiones
#
# - Con el objetivo de encontrar los conjuntos con mayor grado de predictibilidad, contamos la cantidad de conjuntos en los que el rendimiento promedio fue superior al 30% para dos casos:
#
#  **Predictor:** Conjunto que predice a otro conjunto
#
#  **Predecible:** Conjunto que es predecido por otro conjunto

# %%
def conjuntos_predecibles(df,look_back):
    df_temp = pd.DataFrame.pivot_table( df[df['Look Back'] == look_back].drop(['Time','Reg','Results'],1) , index=["Target","Base"], columns=["Look Back"])
    return pd.DataFrame(df_temp[df_temp['%'] > 0.3].count(level=0).sort_values([('%',1)], ascending=False).index.values, columns=["Conjunto"])

# %%
def conjuntos_predictores(df,look_back):
    df_temp = pd.DataFrame.pivot_table( df[df['Look Back'] == look_back].drop(['Time','Reg','Results'],1) , index=["Base","Target"], columns=["Look Back"])
    return pd.DataFrame(df_temp[df_temp['%'] > 0.3].count(level=0).sort_values([('%',1)], ascending=False).index.values, columns=["Conjunto"])

# %%
def predictor_predictable(df,look_back,rango):
    return pd.DataFrame(np.column_stack([conjuntos_predictores(df,look_back)[:rango],conjuntos_predictores(df,look_back).tail(rango),conjuntos_predecibles(df,look_back)[:rango],conjuntos_predecibles(df,look_back).tail(rango)]), columns=['Best Predictor','Worse Predictor','Easier Predictable','Hard Predictable'])

# %%
predictor_predictable(resultados,1,7)
# Out:
#     Best Predictor Worse Predictor Easier Predictable Hard Predictable
# 0         Economia         Publico        Agricultura           Social
# 1            Clima          Social              Deuda         Ambiente
# 2           Urbano         Energia              Salud          Trabajo
# 3          Privado        Ambiente            Privado           Genero
# 4  Infraestructura           Ayuda           Economia        Educacion
# 5            Salud           Deuda             Urbano          Pobreza
# 6           Genero         Pobreza           Comercio          Publico
