# %%
import pandas as pd

datos = pd.read_csv("log.csv").drop('Unnamed: 0', 1)
datos
# Out:
#            Base       Target  Look Back                 Estimator         %  \
# 0   Agricultura  Agricultura          1  Decission Tree Regressor  0.431818
# 1   Agricultura  Agricultura          1   Random Forest Regressor  0.545455
# 2   Agricultura  Agricultura          2  Decission Tree Regressor  0.545455
# 3   Agricultura  Agricultura          2   Random Forest Regressor  0.704545
# 4   Agricultura  Agricultura          3  Decission Tree Regressor  0.477273
# 5   Agricultura  Agricultura          3   Random Forest Regressor  0.568182
# 6   Agricultura     Economia          1  Decission Tree Regressor  0.488095
# 7   Agricultura     Economia          1   Random Forest Regressor  0.603175
# 8   Agricultura     Economia          2  Decission Tree Regressor  0.373016
# 9   Agricultura     Economia          2   Random Forest Regressor  0.583333
# 10  Agricultura     Economia          3  Decission Tree Regressor  0.373016
#
# ...
