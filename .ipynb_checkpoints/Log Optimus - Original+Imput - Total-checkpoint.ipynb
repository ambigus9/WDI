# %%
import pandas as pd
import numpy as np
import time

datos = pd.read_csv("suramerica.csv").drop('Unnamed: 0', 1)
paises = datos['CountryCode'].drop_duplicates().values.tolist()

preprocessing = 'imput'
search = 'original'
year_init = 2012
year_range = 5
look_back = 3
years = range(year_init-year_range+1,year_init+1)[::-1]

agricultura     = open("Indicadores/iagricultura.txt").read().split(',')
ambiente        = open("Indicadores/iambiente.txt").read().split(',')
ayuda           = open("Indicadores/iayuda.txt").read().split(',')
ciencia         = open("Indicadores/iciencia.txt").read().split(',')
clima           = open("Indicadores/iclima.txt").read().split(',')
comercio        = open("Indicadores/icomercio.txt").read().split(',')
deuda           = open("Indicadores/ideuda.txt").read().split(',')
economia        = open("Indicadores/ieconomia.txt").read().split(',')
educacion       = open("Indicadores/ieducacion.txt").read().split(',')
energia         = open("Indicadores/ienergia.txt").read().split(',')
finanzas        = open("Indicadores/ifinanzas.txt").read().split(',')
genero          = open("Indicadores/igenero.txt").read().split(',')
infraestructura = open("Indicadores/iinfraestructura.txt").read().split(',')
pobreza         = open("Indicadores/ipobreza.txt").read().split(',')
privado         = open("Indicadores/iprivado.txt").read().split(',')
publico         = open("Indicadores/ipublico.txt").read().split(',')
salud           = open("Indicadores/isalud.txt").read().split(',')
social          = open("Indicadores/isocial.txt").read().split(',')
trabajo         = open("Indicadores/itrabajo.txt").read().split(',')
urbano          = open("Indicadores/iurbano.txt").read().split(',')


conjunto_nombre = ['Agricultura','Ambiente','Ayuda','Ciencia','Clima','Comercio','Deuda','Economia','Educacion',
                   'Energia','Finanzas','Genero','Infraestructura','Pobreza','Privado','Publico','Salud','Social',
                   'Trabajo','Urbano']
conjunto = [agricultura,ambiente,ayuda,ciencia,clima,comercio,deuda,economia,educacion,energia,finanzas,genero,
            infraestructura,pobreza,privado,publico,salud,social,trabajo,urbano]

# %%
df = pd.read_csv("log_global.csv").drop(['Unnamed: 0'], 1)
df
# Out:
#             Base           Target  Look Back  Reg         %       Time  \
# 0    Agricultura      Agricultura          1   48  0.431818  13.051338
# 1    Agricultura      Agricultura          2   48  0.340909  14.210717
# 2    Agricultura      Agricultura          3   48  0.295455  15.926991
# 3    Agricultura         Ambiente          1   96  0.413333  17.401131
# 4    Agricultura         Ambiente          2   96  0.333333  20.768962
# 5    Agricultura         Ambiente          3   96  0.280000  23.399216
# 6    Agricultura            Ayuda          1   71  0.227273  19.237870
# 7    Agricultura            Ayuda          2   71  0.121212  22.234570
# 8    Agricultura            Ayuda          3   71  0.106061  24.986615
# 9    Agricultura          Ciencia          1   13  0.615385   4.644261
# 10   Agricultura          Ciencia          2   13  0.461538   5.732905
# 11   Agricultura          Ciencia          3   13  0.384615   7.622393
# 12   Agricultura            Clima          1   67  0.618182   9.761890
# 13   Agricultura            Clima          2   67  0.454545  15.512454
# 14   Agricultura            Clima          3   67  0.363636  16.611837
# 15   Agricultura         Comercio          1  142  0.290780  37.243355
# 16   Agricultura         Comercio          2  142  0.212766  41.418816
# 17   Agricultura         Comercio          3  142  0.269504  41.021844
# 18   Agricultura            Deuda          1  229  0.272321  58.016183
# 19   Agricultura            Deuda          2  229  0.232143  62.200208
# 20   Agricultura            Deuda          3  229  0.241071  66.620090
# 21   Agricultura         Economia          1  258  0.408000  52.907268
# 22   Agricultura         Economia          2  258  0.368000  59.518770
# 23   Agricultura         Economia          3  258  0.244000  69.033784
# 24   Agricultura        Educacion          1  168  0.336207  27.362510
# 25   Agricultura        Educacion          2  168  0.310345  30.802537
# 26   Agricultura        Educacion          3  168  0.275862  34.571260
# 27   Agricultura          Energia          1   51  0.480000  11.606488
# 28   Agricultura          Energia          2   51  0.360000  14.607458
# 29   Agricultura          Energia          3   51  0.400000  15.059237
# ..           ...              ...        ...  ...       ...        ...
# 84      Ambiente        Educacion          1  168  0.051724  37.640940
# 85      Ambiente        Educacion          2  168  0.086207  38.568706
# 86      Ambiente        Educacion          3  168  0.068966  42.093181
# 87      Ambiente          Energia          1   31  0.354839   9.474233
# 88      Ambiente          Energia          2   31  0.354839  11.237414
# 89      Ambiente          Energia          3   31  0.387097  11.945566
# 90      Ambiente         Finanzas          1   67  0.266667  18.074520
# 91      Ambiente         Finanzas          2   67  0.216667  19.671318
# 92      Ambiente         Finanzas          3   67  0.216667  21.981956
# 93      Ambiente           Genero          1  177  0.063830  44.698315
# 94      Ambiente           Genero          2  177  0.127660  44.897643
# 95      Ambiente           Genero          3  177  0.092199  49.305028
# 96      Ambiente  Infraestructura          1   36  0.388889  10.930406
# 97      Ambiente  Infraestructura          2   36  0.361111  12.481611
# 98      Ambiente  Infraestructura          3   36  0.333333  14.174309
# 99      Ambiente          Pobreza          1   24  0.000000   9.228677
# 100     Ambiente          Pobreza          2   24  0.090909   9.677484
# 101     Ambiente          Pobreza          3   24  0.090909  11.317532
# 102     Ambiente          Privado          1  165  0.178808  44.615523
# 103     Ambiente          Privado          2  165  0.145695  46.994440
# 104     Ambiente          Privado          3  165  0.172185  51.296179
# 105     Ambiente          Publico          1   97  0.212500  22.449099
# 106     Ambiente          Publico          2   97  0.125000  27.268795
# 107     Ambiente          Publico          3   97  0.250000  26.013757
# 108     Ambiente            Salud          1  152  0.181102  38.657985
# 109     Ambiente            Salud          2  152  0.212598  38.069131
# 110     Ambiente            Salud          3  152  0.220472  43.305107
# 111     Ambiente           Social          1   35  0.228571  11.912568
# 112     Ambiente           Social          2   35  0.200000  12.987520
# 113     Ambiente           Social          3   35  0.200000  15.511530
#
#                                                Results
# 0    [[ 0.54606089]\n [ 0.76620959]\n [ 0.49210446]...
# 1    [[ 0.11246103]\n [ 0.94973832]\n [ 0.32787806]...
# 2    [[ 0.72796651]\n [ 0.68213355]\n [ 0.95292367]...
# 3    [[ 0.95206936]\n [ 0.        ]\n [ 0.16553112]...
# 4    [[ 0.48880441]\n [ 0.92268338]\n [ 0.63249692]...
# 5    [[ 0.58566553]\n [ 0.49375576]\n [ 0.51482956]...
# 6    [[ 1.        ]\n [ 0.61833382]\n [ 0.92726999]...
# 7    [[ 1.        ]\n [ 0.84497427]\n [ 0.93365757]...
# 8    [[ 1.        ]\n [ 0.83993009]\n [ 0.        ]...
# 9    [[ 0.94138361]\n [ 0.97291186]\n [ 0.44853277]...
# 10   [[ 0.98211416]\n [ 0.44334608]\n [ 0.21549627]...
# 11   [[ 0.82588818]\n [ 0.92744057]\n [ 0.7187292 ]...
# 12   [[ 0.21885736]\n [ 0.4885873 ]\n [ 0.        ]...
# 13   [[ 0.05947909]\n [ 0.        ]\n [ 0.        ]...
# 14   [[ 0.45401928]\n [ 0.        ]\n [ 0.65221445]...
# 15   [[ 0.        ]\n [ 0.4946943 ]\n [ 0.        ]...
# 16   [[ 0.        ]\n [ 0.88503864]\n [ 0.        ]...
# 17   [[ 0.        ]\n [ 0.63271434]\n [ 0.22257268]...
# 18   [[ 0.        ]\n [ 0.04789791]\n [ 0.        ]...
# 19   [[  1.70811684e-01]\n [  4.28657686e-01]\n [  ...
# 20   [[ 0.41736569]\n [ 0.37151789]\n [ 0.        ]...
# 21   [[ 0.72053644]\n [ 0.99012996]\n [ 0.35704291]...
# 22   [[ 0.50695228]\n [ 0.94321727]\n [ 0.        ]...
# 23   [[ 0.99981538]\n [ 0.25855884]\n [ 0.20680575]...
# 24   [[ 0.38574369]\n [ 0.54144963]\n [ 0.69588611]...
# 25   [[ 0.60501345]\n [ 0.60227466]\n [ 0.68067087]...
# 26   [[ 0.23266214]\n [ 0.0498088 ]\n [ 0.658135  ]...
# 27   [[ 0.33468884]\n [ 0.23937271]\n [ 0.68691434]...
# 28   [[ 0.06275116]\n [ 0.49575455]\n [ 0.78041702]...
# 29   [[ 0.28146983]\n [ 0.41551421]\n [ 0.        ]...
# ..                                                 ...
# 84   [[ 0.62289984]\n [ 0.47990847]\n [ 0.65550423]...
# 85   [[ 0.58948553]\n [ 0.56512178]\n [ 0.78315984]...
# 86   [[ 0.36112213]\n [ 0.51578583]\n [ 0.69346627]...
# 87   [[ 0.4115681 ]\n [ 0.79621672]\n [ 0.02688236]...
# 88   [[ 0.77833692]\n [ 0.65743537]\n [ 0.8467204 ]...
# 89   [[ 0.27807315]\n [ 0.04729113]\n [ 0.56505963]...
# 90   [[ 0.92936373]\n [ 0.        ]\n [ 0.        ]...
# 91   [[ 0.91311244]\n [ 0.58086421]\n [ 0.29690966]...
# 92   [[ 0.75510058]\n [ 0.301581  ]\n [ 0.28104642]...
# 93   [[ 0.63436423]\n [ 0.54216236]\n [ 0.95638134]...
# 94   [[ 0.63744392]\n [ 0.64120449]\n [ 0.98713118]...
# 95   [[ 0.36432183]\n [ 0.36681707]\n [ 0.90220083]...
# 96   [[ 0.22756962]\n [ 0.51873931]\n [ 0.45121744]...
# 97   [[ 0.93649981]\n [ 0.53377354]\n [ 0.74253879]...
# 98   [[ 0.92985488]\n [ 0.74400919]\n [ 0.70770721]...
# 99   [[ 0.        ]\n [ 0.        ]\n [ 0.66552618]...
# 100  [[ 0.        ]\n [ 0.        ]\n [ 0.36489869]...
# 101  [[ 0.66124155]\n [ 0.        ]\n [ 0.47249402]...
# 102  [[ 0.80380929]\n [ 0.77738939]\n [ 0.01836522]...
# 103  [[ 0.66912125]\n [ 0.68534678]\n [ 0.15053178]...
# 104  [[ 0.64189659]\n [ 0.72382092]\n [ 0.        ]...
# 105  [[ 0.82718757]\n [ 0.93898313]\n [ 0.        ]...
# 106  [[ 0.96321225]\n [ 0.99752206]\n [ 0.        ]...
# 107  [[ 0.82241941]\n [ 0.92570917]\n [ 0.        ]...
# 108  [[ 0.        ]\n [ 0.8252702 ]\n [ 0.        ]...
# 109  [[ 0.        ]\n [ 0.83846235]\n [ 0.57156714]...
# 110  [[ 0.        ]\n [ 0.85407312]\n [ 0.36255644]...
# 111  [[ 0.81880808]\n [ 0.        ]\n [ 0.        ]...
# 112  [[ 0.86529481]\n [ 0.        ]\n [ 0.        ]...
# 113  [[ 0.85019863]\n [ 0.0396653 ]\n [ 0.52528588]...
#
# [114 rows x 7 columns]

# %%
pd.DataFrame.pivot_table(df, index=["Base","Target","Reg"], columns=["Look Back"]).drop(['Time'],1)
# Out:
#                                         %
# Look Back                               1         2         3
# Base        Target          Reg
# Agricultura Agricultura     48   0.431818  0.340909  0.295455
#             Ambiente        96   0.413333  0.333333  0.280000
#             Ayuda           71   0.227273  0.121212  0.106061
#             Ciencia         13   0.615385  0.461538  0.384615
#             Clima           67   0.618182  0.454545  0.363636
#             Comercio        142  0.290780  0.212766  0.269504
#             Deuda           229  0.272321  0.232143  0.241071
#             Economia        258  0.408000  0.368000  0.244000
#             Educacion       168  0.336207  0.310345  0.275862
#             Energia         51   0.480000  0.360000  0.400000
#             Finanzas        67   0.266667  0.283333  0.166667
#             Genero          175  0.345324  0.251799  0.187050
#             Infraestructura 41   0.463415  0.292683  0.219512
#             Pobreza         23   0.200000  0.050000  0.050000
#             Privado         163  0.288591  0.181208  0.221477
#             Publico         97   0.387500  0.337500  0.387500
#             Salud           150  0.432000  0.296000  0.280000
#             Social          35   0.371429  0.285714  0.371429
#             Trabajo         130  0.220472  0.149606  0.102362
#             Urbano          24   0.444444  0.444444  0.500000
# Ambiente    Agricultura     32   0.343750  0.156250  0.187500
#             Ambiente        112  0.379310  0.264368  0.275862
#             Ayuda           71   0.060606  0.090909  0.060606
#             Ciencia         13   0.076923  0.230769  0.384615
#             Clima           31   0.466667  0.500000  0.433333
#             Comercio        144  0.195804  0.244755  0.258741
#             Deuda           229  0.178571  0.147321  0.156250
#             Economia        239  0.298701  0.341991  0.341991
#             Educacion       168  0.051724  0.086207  0.068966
#             Energia         31   0.354839  0.354839  0.387097
#             Finanzas        67   0.266667  0.216667  0.216667
#             Genero          177  0.063830  0.127660  0.092199
#             Infraestructura 36   0.388889  0.361111  0.333333
#             Pobreza         24   0.000000  0.090909  0.090909
#             Privado         165  0.178808  0.145695  0.172185
#             Publico         97   0.212500  0.125000  0.250000
#             Salud           152  0.181102  0.212598  0.220472
#             Social          35   0.228571  0.200000  0.200000

# %%
def tabla_base(indicadores):
    tab = pd.DataFrame.pivot_table(datos, values='Value', index=['CountryCode', 'Year'], columns=['IndicatorCode']).loc[(paises,years),indicadores].sortlevel(["CountryCode","Year"], ascending=[True,False])
    return tab

# %%
def buscar_resultados(df,indicador_1,indicador_2,look_back):
    #Buscamos Resultados en base al conjunto de indicadores Base, Target y Look Back
    temp = df[(df['Base']==indicador_1)&(df['Target']==indicador_2)&(df['Look Back'] == look_back)]['Results'].values[0]
    
    df_temp = temp.replace("'","").replace("[","").replace("]","").replace(" ","").split('\n')

    results = []
    for i in df_temp: 
        results.append(float(i))
    
    # Códigos de los indicadores con registros   
    for i in range(len(conjunto_nombre)):
        
        if indicador_1 == conjunto_nombre[i]:
            indicador1 = conjunto[i]
        if indicador_2 == conjunto_nombre[i]:
            indicador2 = conjunto[i]

            df = pd.DataFrame(indicador2)
            # Filtro indicadores repetidos
            if(indicador1!=indicador2):
                indicador2 = np.array(df.loc[~df.ix[:,0].isin(indicador1)]).flatten()
            df_zeros = tabla_base(indicador2).dropna(how='all',axis=1)
                
    icodes = df_zeros.columns.values

    # Buscamos Nombres de los Códigos de los Indicadores
    nombres = pd.DataFrame(datos).loc[:,['IndicatorName','IndicatorCode']].set_index('IndicatorCode').loc[icodes].drop_duplicates()

    # Concatenamos Resultados y Nombres, Reindexando en base a los nombres
    df_results = pd.DataFrame(np.column_stack([nombres,results]),columns=['Indicadores','Resultados'])
    
    return df_results

# %%
buscar_resultados(df,'Agricultura','Ambiente',1).head()
# Out:
#                                          Indicadores Resultados
# 0            Access to electricity (% of population)   0.952069
# 1         Access to non-solid fuel (% of population)          0
# 2  Adjusted net savings, excluding particulate em...   0.165531
# 3  Adjusted net savings, excluding particulate em...   0.820164
# 4  Adjusted net savings, including particulate em...   0.136292

# %%
df_temp['Resultados'].values
# Out:
# array([0.33468884, 0.23937271, 0.68691434, 0.6899374, 0.92280695,
#        0.83917604, 0.75027226, 0.78725889, 0.80230933, 0.97852243,
#        0.98299894, 0.74511662, 0.97536709, 0.05991668, 0.93603147,
#        0.9492736, 0.98298077, 0.95444889, 0.84523051, 0.98257186,
#        0.82129022, 0.82621798, 0.74838047, 0.9318339, 0.9861457,
#        0.99729696, 0.57245395, 0.99250713, 0.93662465, 0.0, 0.94725046,
#        0.8757547, 0.79547108, 0.88789482, 0.92236515, 0.0, 0.98298876,
#        0.71072236, 0.43302891, 0.98384238, 0.97326975, 0.92022872,
#        0.95881053, 0.68083194, 0.63733505, 0.12402685, 0.91195519,
#        0.94845022, 0.97541193, 0.82942503], dtype=object)

# %%
import plotly.plotly as py
import plotly.graph_objs as go

df_temp = buscar_resultados(df,'Agricultura','Energia',1)

data = [go.Bar(
            x= df_temp['Indicadores'],
            y= df_temp['Resultados'],

    marker=dict(     
        color = df_temp['Resultados'].values , #set color equal to a variable
        colorscale ='Viridis',
        ),
    )]

layout = go.Layout(
    title='Agricultura - Energia',
)

py.iplot(data, filename='Agricultura - Energia')
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-70-9f178a0a16a7> in <module>()
#      20 )
#      21
# ---> 22 py.iplot(data, filename='Agricultura - Energia')
#
# /home/familia-plazas/anaconda2/lib/python2.7/site-packages/plotly/plotly/plotly.pyc in iplot(figure_or_data, **plot_options)
#     132     if 'auto_open' not in plot_options:
#     133         plot_options['auto_open'] = False
# --> 134     url = plot(figure_or_data, **plot_options)
#     135
#     136     if isinstance(figure_or_data, dict):
#
# /home/familia-plazas/anaconda2/lib/python2.7/site-packages/plotly/plotly/plotly.pyc in plot(figure_or_data, validate, **plot_options)
#     225     data = fig.get('data', [])
#     226     plot_options['layout'] = fig.get('layout', {})
# --> 227     response = v1.clientresp(data, **plot_options)
#     228
#     229     # Check if the url needs a secret key
#
# /home/familia-plazas/anaconda2/lib/python2.7/site-packages/plotly/api/v1/clientresp.pyc in clientresp(data, **kwargs)
#      33
#      34     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 35     response = request('post', url, data=payload)
#      36
#      37     # Old functionality, just keeping it around.
#
# /home/familia-plazas/anaconda2/lib/python2.7/site-packages/plotly/api/v1/utils.pyc in request(method, url, **kwargs)
#      84         content = response.content if response else 'No content'
#      85         raise exceptions.PlotlyRequestError(message, status_code, content)
# ---> 86     validate_response(response)
#      87     return response
#
# /home/familia-plazas/anaconda2/lib/python2.7/site-packages/plotly/api/v1/utils.pyc in validate_response(response)
#      36         message = content if content else 'No Content'
#      37
# ---> 38     raise exceptions.PlotlyRequestError(message, status_code, content)
#      39
#      40
#
# PlotlyRequestError: Hey there! You've hit one of our API request limits.
#
# To get unlimited API calls(10,000/day), please upgrade to a paid plan.
#
# UPGRADE HERE: https://goo.gl/i7glmM
#
# Thanks for using Plotly! Happy Plotting!

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace0 = go.Bar(
    x=['Feature A', 'Feature B', 'Feature C',
       'Feature D', 'Feature E'],
    y=[20, 14, 23, 25, 22],
    marker=dict(     
        color = np.random.randn(500),
        colorscale='Viridis'),
)

data = [trace0]
layout = go.Layout(
    title='Agricultura - Energia',
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='color-bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ambigus9/166.embed" height="525px" width="100%"></iframe>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_temp = buscar_resultados(df,'Agricultura','Energia',1)

ax = sns.barplot(x="Indicadores", y="Resultados", data=df_temp)
plt.setp(ax.get_xticklabels(), rotation=90)
plt.figure(figsize=(20, 16))
plt.show()

# %%
def graficar(df,look_back):
    import seaborn as sns
    import matplotlib.pyplot as plt
    df_temp = df[df['Look Back'] == 1].drop(['Time','Reg','Look Back','Results'], 1)
    df_temp = pd.DataFrame(np.array(pd.DataFrame.pivot_table(df_temp, index=["Base"], columns=["Target"])), index=[conjunto_nombre], columns=[conjunto_nombre])
    ax = sns.heatmap(df_temp)
    plt.title('Look back = '+str(look_back), size=15)
    return plt.show()

# %%
graficar(df,1)

# %%
import plotly 
plotly.tools.set_credentials_file(username='ambigus9', api_key='FI71OMtckBFCe5LTU1CL')
