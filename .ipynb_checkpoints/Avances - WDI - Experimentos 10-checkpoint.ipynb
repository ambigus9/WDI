# %% [markdown]
# # Avance Indicadores de Desarrollo Mundial

# %% [markdown]
# Las herramientas que utilizaré para el análisis inicial serán plot.ly y pandas.Es necesario instalar plotly y tener un usuario con su respectiva API Key, aquí la documentación respectiva: [Plot.ly](https://plot.ly/python/)
#
# Cargamos el dataset y los parámetros de plot.ly

# %%
import numpy as np
import pandas as pd
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
import time

plotly.tools.set_credentials_file(username='ambigus9', api_key='VIIp594gf158yUUVfCUK')

datos = pd.read_csv("world-development-indicators/Indicators.csv")
datos.head()
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
#
#     IndicatorCode  Year         Value
# 0     SP.ADO.TFRT  1960  1.335609e+02
# 1     SP.POP.DPND  1960  8.779760e+01
# 2  SP.POP.DPND.OL  1960  6.634579e+00
# 3  SP.POP.DPND.YG  1960  8.102333e+01
# 4  MS.MIL.XPRT.KD  1960  3.000000e+06

# %% [markdown]
# ## Filtramos el dataset original en base a los diversos Continentes

# %% [markdown]
# Filtramos el dataset original en base a los diversos Continentes

# %%
def filtro_continentes(datos,continente):    
    d = datos['CountryName'].values.tolist()
    indices = list()
    for i in continente:
        b = i
        offset = 0;
        for j in range(d.count(b)):
            indices.append(d.index(b,offset))
            offset = indices[-1]+1
    continente = datos.reindex([indices])
    return continente

# %%
suramerica = np.array(['Antigua and Barbuda','Argentina','Aruba','Bahamas, The','Barbados','Belize','Bolivia','Brazil','Cayman Islands','Chile','Colombia','Costa Rica','Cuba','Curacao','Dominica','Dominican Republic','Ecuador','El Salvador','Grenada','Guatemala','Guyana','Haiti','Honduras','Jamaica','Mexico','Nicaragua','Panama','Paraguay','Peru','Puerto Rico','Sint Maarten (Dutch part)','St. Kitts and Nevis','St. Lucia','St. Martin (French part)','St. Vincent and the Grenadines','Suriname','Trinidad and Tobago','Turks and Caicos Islands','Uruguay','Venezuela, RB','Virgin Islands (U.S.)'])
europa = np.array(['Albania','Andorra','Armenia','Austria','Azerbaijan','Belarus','Belgium','Bosnia and Herzegovina','Bulgaria','Channel Islands','Croatia','Cyprus','Czech Republic','Denmark','Estonia','Faeroe Islands','Finland','France','Georgia','Germany','Greece','Greenland','Hungary','Iceland','Ireland','Isle of Man','Italy','Kazakhstan','Kosovo','Kyrgyz Republic','Latvia','Liechtenstein','Lithuania','Luxembourg','Macedonia, FYR','Moldova','Monaco','Montenegro','Netherlands','Norway','Poland','Portugal','Romania','Russian Federation','San Marino','Serbia','Slovak Republic','Slovenia','Spain','Sweden','Switzerland','Tajikistan','Turkey','Turkmenistan','Ukraine','United Kingdom','Uzbekistan'])
este = np.array(['American Samoa','Australia','Brunei Darussalam','Cambodia','China','Fiji','French Polynesia','Guam','Hong Kong SAR, China','Indonesia','Japan','Kiribati','Korea, Dem. Rep.','Korea, Rep.','Lao PDR','Macao SAR, China','Malaysia','Marshall Islands','Micronesia, Fed. Sts.','Mongolia','Myanmar','New Caledonia','New Zealand','Northern Mariana Islands','Palau','Papua New Guinea','Philippines','Samoa','Singapore','Solomon Islands','Thailand','Timor-Leste','Tonga','Tuvalu','Vanuatu','Vietnam'])
africa = np.array(['Algeria','Bahrain','Djibouti','Egypt, Arab Rep.','Iran, Islamic Rep.','Iraq','Israel','Jordan','Kuwait','Lebanon','Libya','Malta','Morocco','Oman','Qatar','Saudi Arabia','Syrian Arab Republic','Tunisia','United Arab Emirates','West Bank and Gaza','Yemen, Rep.'])
sudafrica = np.array(['Angola','Benin','Botswana','Burkina Faso','Burundi','Cabo Verde','Cameroon','Central African Republic','Chad','Comoros','Congo, Dem. Rep.','Congo, Rep.','Equatorial Guinea','Eritrea','Ethiopia','Gabon','Gambia, The','Ghana','Guinea','Guinea-Bissau','Kenya','Lesotho','Liberia','Madagascar','Malawi','Mali','Mauritania','Mauritius','Mozambique','Namibia','Niger','Nigeria','Rwanda','Sao Tome and Principe','Senegal','Seychelles','Sierra Leone','Somalia','South Africa','South Sudan','Sudan','Swaziland','Tanzania','Togo','Uganda','Zambia','Zimbabwe'])

# %% [markdown]
# Guardamos en un CSV para cada caso

# %%
filtro_continentes(datos,suramerica).to_csv('suramerica.csv')
filtro_continentes(datos,europa).to_csv('europa.csv')
filtro_continentes(datos,este).to_csv('este.csv')
filtro_continentes(datos,africa).to_csv('africa.csv')
filtro_continentes(datos,sudafrica).to_csv('sudafrica.csv')

# %% [markdown]
# ## Filtro de frecuencia indicador en serie temporal

# %% [markdown]
# Por medio de la siguiente función buscamos derminar la cantidad de registros para cada indicador en cada continente:
#
# - Cargamos el CSV del continente, agrupamos en base a cuatro columnas: Nombre del Indicador y Nombre del Pais, Código del indicador y Código del Pais
# - Utilizamos el método count() para efectuar un conteo de las repeticiones de los indicadores registrados en la serie temporal

# %%
def filtro_frecuencia_indicador(datos_continente):
    temp = datos_continente.drop('Unnamed: 0', 1).groupby(['IndicatorName','CountryName','IndicatorCode','CountryCode'])
    agrupado = temp.count()
    return agrupado

# %% [markdown]
# Guardarmos en un CSV para cada caso

# %%
filtro_frecuencia_indicador(pd.read_csv("suramerica.csv")).to_csv('suramerica2.csv')
filtro_frecuencia_indicador(pd.read_csv("europa.csv")).to_csv('europa2.csv')
filtro_frecuencia_indicador(pd.read_csv("este.csv")).to_csv('este2.csv')
filtro_frecuencia_indicador(pd.read_csv("africa.csv")).to_csv('africa2.csv')
filtro_frecuencia_indicador(pd.read_csv("sudafrica.csv")).to_csv('sudafrica2.csv')

# %% [markdown]
# ## Media de las Frecuencias

# %% [markdown]
# Por medio de la siguiente función calculamos para un conjunto de indicadores en específico la Media de la frencuencia de los indicadores

# %%
def media_frencuencias(continente,datos_continente,indicadores):
    filtro = []
    temporal = list()
    grupo = list()
    output = {}
    
    for k in range(len(datos_continente)):
        cn = datos_continente['CountryName'][k]
        indicator_code = datos_continente['IndicatorCode'][k]

        if cn in continente and indicator_code in indicadores:
            year = datos_continente['Year'][k]

            if cn not in output.keys():
                output[cn] = []
            output[cn].append(year)
       
    for p in continente:
        if p not in output.keys():
            temporal.append(np.array([p,0]))

            
    for o in output:
        temporal.append(np.array([o,np.mean(output.get(o))]))

    temporal = sorted(temporal,key=lambda x:x[0])  

    for i in temporal:
        filtro.append(i[1])
    grupo = filtro
    return grupo

# %% [markdown]
# ### Conjunto de Indicadores

# %% [markdown]
# Se agrupan los indicadores en varios conjuntos según banco mundial. Para más información consulte [aquí](http://data.worldbank.org/indicator?tab=all)

# %%
agricultura = np.array(['EG.ELC.ACCS.RU.ZS','EG.NSF.ACCS.RU.ZS','AG.LND.IRIG.AG.ZS','AG.LND.AGRI.ZS','AG.LND.AGRI.K2','AG.AGR.TRAC.NO','AG.LND.TRAC.ZS','EN.ATM.METH.AG.ZS','EN.ATM.METH.AG.KT.CE','EN.ATM.NOXE.AG.ZS','EN.ATM.NOXE.AG.KT.CE','TX.VAL.AGRI.ZS.UN','TM.VAL.AGRI.ZS.UN','EA.PRD.AGRI.KD','NV.AGR.TOTL.ZS','NV.AGR.TOTL.CD','ER.H2O.FWAG.ZS','AG.LND.ARBL.ZS','AG.LND.ARBL.HA.PC','AG.LND.ARBL.HA','AG.LND.PRCP.MM','AG.PRD.CREL.MT','AG.YLD.CREL.KG','AG.PRD.CROP.XD','SL.AGR.EMPL.ZS','SL.AGR.EMPL.FE.ZS','SL.AGR.EMPL.MA.ZS','AG.CON.FERT.PT.ZS','AG.CON.FERT.ZS','AG.PRD.FOOD.XD','AG.LND.FRST.ZS','AG.LND.FRST.K2','SH.STA.ACSN.RU','SH.H2O.SAFE.RU.ZS','AG.LND.TOTL.K2','AG.LND.CREL.HA','AG.PRD.LVSK.XD','AG.LND.CROP.ZS','AG.LND.TOTL.RU.K2','AG.LND.EL5M.RU.ZS','AG.LND.EL5M.RU.K2','SP.RUR.TOTL','SP.RUR.TOTL.ZS','SP.RUR.TOTL.ZG','EN.POP.EL5M.RU.ZS','SI.POV.RUGP','SI.POV.RUHC','AG.SRF.TOTL.K2'])
ayuda = np.array(['DT.DOD.MDRI.CD','BX.GRT.EXTA.CD.WD','DT.DIS.IDAG.CD','SH.STA.ACSN','SH.TBS.INCD','SI.DST.FRST.20','SH.STA.MMRT','SH.DYN.MORT','DT.ODA.ODAT.GN.ZS','DT.ODA.ODAT.XP.ZS','DT.ODA.ODAT.GI.ZS','DT.ODA.ODAT.MP.ZS','DT.ODA.ODAT.PC.ZS','DC.DAC.AUSL.CD','DC.DAC.AUTL.CD','DC.DAC.BELL.CD','DC.DAC.CANL.CD','DC.DAC.CZEL.CD','DC.DAC.DNKL.CD','DC.DAC.CECL.CD','DC.DAC.FINL.CD','DC.DAC.FRAL.CD','DC.DAC.DEUL.CD','DC.DAC.GRCL.CD','DC.DAC.ISLL.CD','DC.DAC.IRLL.CD','DC.DAC.ITAL.CD','DC.DAC.JPNL.CD','DC.DAC.KORL.CD','DC.DAC.LUXL.CD','DC.DAC.NLDL.CD','DC.DAC.NZLL.CD','DC.DAC.NORL.CD','DC.DAC.POLL.CD','DC.DAC.PRTL.CD','DC.DAC.SVKL.CD','DC.DAC.SVNL.CD','DC.DAC.ESPL.CD','DC.DAC.SWEL.CD','DC.DAC.CHEL.CD','DC.DAC.TOTL.CD','DC.DAC.GBRL.CD','DC.DAC.USAL.CD','SM.POP.NETM','DT.ODA.OATL.KD','DT.ODA.OATL.CD','DT.ODA.ALLD.KD','DT.ODA.ALLD.CD','DT.ODA.ODAT.KD','DT.ODA.ODAT.CD','DT.NFL.IAEA.CD','DT.NFL.IFAD.CD','DT.NFL.UNAI.CD','DT.NFL.UNDP.CD','DT.NFL.UNEC.CD','DT.NFL.UNFP.CD','DT.NFL.UNCR.CD','DT.NFL.UNCF.CD','DT.NFL.UNPB.CD','DT.NFL.UNRW.CD','DT.NFL.UNTA.CD','DT.NFL.WFPG.CD','DT.NFL.WHOL.CD','SI.POV.DDAY','SH.STA.ANVC.ZS','SH.DYN.AIDS.ZS','SH.STA.STNT.ZS','SE.PRM.CMPT.ZS','SE.ENR.PRSC.FM.ZS','BX.GRT.TECH.CD.WD','SL.EMP.VULN.ZS'])
clima = np.array(['EG.ELC.ACCS.ZS','AG.LND.IRIG.AG.ZS','AG.LND.AGRI.ZS','AG.LND.AGRI.K2','NV.AGR.TOTL.ZS','ER.H2O.FWTL.ZS','ER.H2O.FWTL.K3','AG.LND.ARBL.ZS','AG.LND.PRCP.MM','EN.ATM.CO2E.KD.GD','EN.ATM.CO2E.PP.GD.KD','EN.ATM.CO2E.PP.GD','EN.ATM.CO2E.KT','EN.ATM.CO2E.PC','EN.ATM.CO2E.GF.ZS','EN.ATM.CO2E.GF.KT','EN.ATM.CO2E.LF.ZS','EN.ATM.CO2E.LF.KT','EN.ATM.CO2E.SF.ZS','EN.ATM.CO2E.SF.KT','EN.ATM.CO2E.EG.ZS','IQ.CPA.PUBS.XQ','AG.YLD.CREL.KG','SH.MED.CMHW.P3','EN.CLC.DRSK.XQ','EN.CLC.MDAT.ZS','IC.BUS.EASE.XQ','EG.USE.ELEC.KH.PC','EG.ELC.COAL.ZS','EG.ELC.HYRO.ZS','EG.ELC.NGAS.ZS','EG.ELC.NUCL.ZS','EG.ELC.PETR.ZS','EG.ELC.RNWX.ZS','EG.ELC.RNWX.KH','EG.USE.PCAP.KG.OE','EG.USE.COMM.GD.PP.KD','BX.KLT.DINV.WD.GD.ZS','AG.LND.FRST.ZS','AG.LND.FRST.K2','EN.CLC.GHGR.MT.CE','EN.ATM.HFCG.KT.CE','SH.STA.ACSN','SH.H2O.SAFE.ZS','SH.H2O.SAFE.RU.ZS','SH.H2O.SAFE.UR.ZS','AG.LND.EL5M.ZS','ER.MRN.PTMR.ZS','EN.ATM.METH.ZG','EN.ATM.METH.KT.CE','SH.DYN.MORT','EN.ATM.NOXE.ZG','EN.ATM.NOXE.KT.CE','EN.ATM.GHGO.ZG','EN.ATM.GHGO.KT.CE','EN.ATM.PFCG.KT.CE','SP.POP.GROW','EN.URB.MCTY.TL.ZS','EN.POP.EL5M.ZS','SP.POP.TOTL','SI.POV.DDAY','SH.STA.MALN.ZS','SE.PRM.CMPT.ZS','EG.ELC.RNEW.ZS','EG.FEC.RNEW.ZS','AG.LND.EL5M.RU.ZS','AG.LND.EL5M.RU.K2','EN.POP.EL5M.RU.ZS','EN.ATM.SF6G.KT.CE','SE.ENR.PRSC.FM.ZS','ER.PTD.TOTL.ZS','ER.LND.PTLD.ZS','EN.ATM.GHGT.ZG','EN.ATM.GHGT.KT.CE','AG.LND.EL5M.UR.ZS','AG.LND.EL5M.UR.K2','SP.URB.TOTL','SP.URB.TOTL.IN.ZS','SP.URB.GROW','EN.POP.EL5M.UR.ZS'])
economia = np.array(['PA.NUS.PPP.05','PA.NUS.PRVT.PP.05','NY.ADJ.NNTY.KD.ZG','NY.ADJ.NNTY.KD','NY.ADJ.NNTY.CD','NY.ADJ.NNTY.PC.KD.ZG','NY.ADJ.NNTY.PC.KD','NY.ADJ.NNTY.PC.CD','NY.ADJ.SVNX.GN.ZS','NY.ADJ.SVNX.CD','NY.ADJ.SVNG
','SE.SEC.ENRL.UP.TC.ZS','SE.ENR.PRIM.FM.ZS','SE.ENR.PRSC.FM.ZS','SE.PRM.ENRR.FE','SE.PRM.NENR.FE','SE.PRM.ENRR.MA','SE.PRM.NENR.MA','SE.ENR.SECO.FM.ZS','SE.SEC.ENRR.FE','SE.SEC.NENR.FE','SE.SEC.ENRR.MA','SE.SEC.NENR.MA','SE.ENR.TERT.FM.ZS','SE.TER.ENRR.FE','SE.TER.ENRR.MA','SE.SEC.ENRL.FE.ZS','SE.SEC.TCHR.FE.ZS','SE.PRM.PRS5.ZS','SE.PRM.PRSL.ZS','SE.PRM.PRSL.FE.ZS','SE.PRM.PRSL.MA.ZS','SE.PRM.TCHR','SE.SEC.TCHR','SE.SEC.TCHR.FE','SE.TER.TCHR.FE.ZS','SE.PRM.DURS','SE.SEC.DURS','SE.SEC.TCAQ.LO.ZS','SE.SEC.TCAQ.LO.FE.ZS','SE.SEC.TCAQ.LO.MA.ZS','SE.PRE.TCAQ.ZS','SE.PRE.TCAQ.FE.ZS','SE.PRE.TCAQ.MA.ZS','SE.SEC.TCAQ.UP.ZS','SE.SEC.TCAQ.UP.FE.ZS','SE.SEC.TCAQ.UP.MA.ZS','SL.UEM.TOTL.FE.ZS','SL.UEM.TOTL.MA.ZS','SL.UEM.TOTL.ZS','SE.ADT.1524.LT.ZS'])
energia = np.array(['EG.ELC.ACCS.ZS','EG.ELC.ACCS.RU.ZS','EG.ELC.ACCS.UR.ZS','EG.NSF.ACCS.ZS','EG.NSF.ACCS.RU.ZS','EG.NSF.ACCS.UR.ZS','NY.ADJ.DNGY.GN.ZS','NY.ADJ.DNGY.CD','NY.ADJ.DMIN.GN.ZS','NY.ADJ.DMIN.CD','NY.ADJ.DRES.GN.ZS','EG.USE.COMM.CL.ZS','EN.ATM.CO2E.GF.ZS','EN.ATM.CO2E.LF.KT','EG.USE.CRNW.ZS','IC.ELC.DURS','EG.USE.ELEC.KH.PC','EG.ELC.LOSS.ZS','EG.ELC.COAL.ZS','EG.ELC.HYRO.ZS','EG.ELC.NGAS.ZS','EG.ELC.NUCL.ZS','EG.ELC.PETR.ZS','EG.ELC.FOSL.ZS','EG.ELC.RNWX.ZS','EG.ELC.RNWX.KH','EG.IMP.CONS.ZS','EG.EGY.PRIM.PP.KD','EN.ATM.METH.EG.ZS','EG.USE.PCAP.KG.OE','EG.USE.COMM.GD.PP.KD','IC.FRM.BNKS.ZS','EG.USE.COMM.FO.ZS','TX.VAL.FUEL.ZS.UN','TM.VAL.FUEL.ZS.UN','EG.GDP.PUSE.KO.PP','EG.GDP.PUSE.KO.PP.KD','IE.PPI.ENGY.CD','EN.ATM.METH.EG.KT.CE','NY.GDP.MINR.RT.ZS','NY.GDP.NGAS.RT.ZS','EN.ATM.NOXE.EG.ZS','EN.ATM.NOXE.EG.KT.CE','NY.GDP.PETR.RT.ZS','TX.VAL.MMTL.ZS.UN','TM.VAL.MMTL.ZS.UN','EP.PMP.DESL.CD','EP.PMP.SGAS.CD','EG.ELC.RNEW.ZS','EG.FEC.RNEW.ZS','IC.ELC.TIME','NY.GDP.TOTL.RT.ZS','IC.FRM.OUTG.ZS'])
# %% [markdown]
# ## Tabla de la Media de Frecuencias

# %% [markdown]
# Por medio de la siguiente función consolidamos la tabla de la media de frecuencias

# %%
def tabla_media_frecuencias(continente,datos_continente):
    gigante = []
    filtro_global = np.array([agricultura,ayuda,clima,economia,educacion,energia,ambiente,deuda,finanzas,genero,salud,infraestructura,pobreza,privado,publico,ciencia,social,trabajo,comercio,urbano])
    for i in range(len(filtro_global)):
        gigante.append(media_frencuencias(continente,datos_continente,filtro_global[i]))
    gigante = zip(*gigante)
    return gigante

# %%
nombre_global = np.array(['Agricultura y Desarrollo Rural','Ayuda y Efectividad','Cambio climatico','Economía y Crecimiento','Educación','Energía y Miniería','Ambiente','Deuda Externa','Sector Financiero','Género','Salud','Infraestructura','Pobreza','Sector Privado','Sector Público','Ciencia y Tecnología','Desarrollo Social','Protección Social y Trabajo','Comercio','Desarrollo Urbano'])
pd.DataFrame(tabla_media_frecuencias(suramerica,pd.read_csv("suramerica2.csv")), index=suramerica, columns=nombre_global)
# Out:
#                                Agricultura y Desarrollo Rural  \
# Antigua and Barbuda                             33.6388888889
# Argentina                                       35.1904761905
# Aruba                                           31.4782608696
# Bahamas, The                                    38.2941176471
# Barbados                                        38.7575757576
# Belize                                          36.0277777778
# Bolivia                                          34.488372093
# Brazil                                          35.9285714286
# Cayman Islands                                  34.1739130435
# Chile                                           35.1860465116
# Colombia                                        34.0227272727
# Costa Rica                                      33.0930232558
# Cuba                                            33.1463414634
# Curacao                                         46.1666666667
# ...

# %% [markdown]
# ## Gráfica de la Media de Frecuencias

# %% [markdown]
# Graficamos un mapa de densidad con los resultados

# %%
def grafica_media_frecuencias(continente,datos_continente):
    data = [
        go.Heatmap(
            z=tabla_media_frecuencias(continente,datos_continente),
            x=nombre_global,
            y=continente,
            colorscale='Viridis'
        )
    ]
    return py.iplot(data, filename='Indicadores')

# %%
grafica_media_frecuencias(suramerica,pd.read_csv("suramerica2.csv"))
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ambigus9/120.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### Filtro Indicadores

# %%
def filtro_indicadores(continente,datos_continente,indicadores):
    indices = list()
    
    for k in range(len(datos_continente)):
        cn = datos_continente['CountryName'][k]
        indicator_code = datos_continente['IndicatorCode'][k]

        if cn in continente and indicator_code in indicadores:
            indices.append(k)
    
    return datos_continente.reindex([indices])

# %% [markdown]
# ### Gráfica Filtro Indicadores

# %%
def grafica_filtro_indicadores(continente,datos_continente,indicadores):
    suramerica_indicadores = filtro_indicadores(continente,datos_continente,indicadores)
    data = [
        go.Heatmap(
            z=suramerica_indicadores['Year'].values.tolist(),
            x=suramerica_indicadores['IndicatorName'].values.tolist(),
            y=suramerica_indicadores['CountryName'].values.tolist(),
            colorscale='Viridis'
        )
    ]
    return py.iplot(data, filename='Grupo de indicadores - Suramerica')

# %% [markdown]
# ### Tabla 1

# %%
def tabla_1(continente,datos_continente,x_indicators,y_indicator,years):
    
    datos = datos_continente
    paises = continente
                
    #Creamos una lista temporal que contiene todos los valores de los indicadores en 0          
    indicadores = list()
    for i in x_indicators: indicadores.append(i)
    for i in y_indicator: indicadores.append(i)
    temporal = list()

    for i in paises:
        for j in indicadores:
            for k in years:
                temporal.append([i,k,j,0.])
                
    #Agregamos valores de los indicadores a nuestra lista temporal              
    for k in range(len(datos)):
        cn = datos['CountryName'][k]
        indicator_code = datos['IndicatorCode'][k]
        indicator_name = datos['IndicatorName'][k]
        y = datos['Year'][k]
        v = datos['Value'][k]

        for i in range(len(temporal)):
            if cn == temporal[i][0] and y == temporal[i][1] and indicator_code == temporal[i][2]:
                temporal[i][3] = v
        
    #Consolidamos la tabla 1 en base a la lista temporal   
    valores = list()
    paises2 = list()
    years2 = list()
    matriz = []

    for i in paises:
        for j in years: paises2.append(i)
    matriz.append(paises2)        

    for i in temporal: years2.append(i[1])
    matriz.append(years2)

    for i in range(len(indicadores)):
        for k in range(len(temporal)):
            if indicadores[i] == temporal[k][2]:
                valores.append(temporal[k][3])
        matriz.append(valores)
        valores = list()

    matriz = np.array(matriz)
    return matriz

# %% [markdown]
# ### Suramérica - Economía

# %% [markdown]
# Primero probaremos con el conjunto de Economía debido a que tienen la media más alta la mayoría de paises

# %%
def grafica_filtro_indicadores(continente,datos_continente,indicadores):
    suramerica_indicadores = filtro_indicadores(continente,datos_continente,indicadores)
    data = [
        go.Heatmap(
            z=suramerica_indicadores['Year'].values.tolist(),
            x=suramerica_indicadores['IndicatorName'].values.tolist(),
            y=suramerica_indicadores['CountryName'].values.tolist(),
            colorscale='Viridis'
        )
    ]
    return py.iplot(data, filename='Economía - Suramerica')
grafica_filtro_indicadores(suramerica,pd.read_csv("suramerica2.csv"),economia)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ambigus9/132.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ###  Suramérica - Economia - GDP

# %% [markdown]
# Probaremos con los indicadores de GDP debido a que son los que presentan mayor cantidad de registros de años

# %%
name_indicators = np.array(['GDP (constant LCU)','GDP (current LCU)','GDP (current US$)','GDP at market prices (constant 2010 US$)','GDP deflator (base year varies by country)','GDP growth (annual %)','GDP per capita (constant 2010 US$)','GDP per capita (constant LCU)','GDP per capita (current LCU)','GDP per capita (current US$)','GDP per capita growth (annual %)','GDP per capita, PPP (constant 2011 international $)','GDP per capita, PPP (current international $)','GDP, PPP (constant 2011 international $)','GDP, PPP (current international $)'])
x_name_indicators = np.array(['GDP (constant LCU)','GDP (current LCU)','GDP (current US$)','GDP at market prices (constant 2010 US$)','GDP deflator (base year varies by country)','GDP growth (annual %)','GDP per capita (constant 2010 US$)','GDP per capita (constant LCU)','GDP per capita (current LCU)','GDP per capita (current US$)','GDP per capita growth (annual %)','GDP per capita, PPP (constant 2011 international $)','GDP per capita, PPP (current international $)','GDP, PPP (constant 2011 international $)'])
y_name_indicator = np.array(['GDP, PPP (current international $)'])
x_indicators = np.array(['NY.GDP.MKTP.KN','NY.GDP.MKTP.CN','NY.GDP.MKTP.CD','NY.GDP.MKTP.KD','NY.GDP.DEFL.ZS','NY.GDP.MKTP.KD.ZG','NY.GDP.PCAP.KD','NY.GDP.PCAP.KN','NY.GDP.PCAP.CN','NY.GDP.PCAP.CD','NY.GDP.PCAP.KD.ZG','NY.GDP.PCAP.PP.KD','NY.GDP.PCAP.PP.CD','NY.GDP.MKTP.PP.KD'])
y_indicator = np.array(['NY.GDP.MKTP.PP.CD'])
years = np.array([2008,2009,2010,2011,2012])

# %% [markdown]
# ### Suramérica - Economia - GDP - Tabla 1

# %%
start_time = time.time()

tabla1 = tabla_1(suramerica,pd.read_csv("suramerica.csv"),x_indicators,y_indicator,years)
tabla2 = np.array(zip(*tabla1[2:]))

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 687.145999908 seconds ---

# %%
pd.DataFrame(tabla2).to_csv('economia7.csv')
pd.DataFrame(zip(*tabla1),columns=np.hstack((np.array(['Pais']),np.array(['Año']),x_name_indicators,y_name_indicator)))
# Out:
#                          Pais   Año  GDP (constant LCU)  GDP (current LCU)  \
# 0         Antigua and Barbuda  2008        3.358406e+09       3.637845e+09
# 1         Antigua and Barbuda  2009        2.954188e+09       3.257308e+09
# 2         Antigua and Barbuda  2010        2.743171e+09       3.065955e+09
# 3         Antigua and Barbuda  2011        2.693974e+09       3.050780e+09
# 4         Antigua and Barbuda  2012        2.802259e+09       3.252725e+09
# 5                   Argentina  2008        7.058647e+11       1.283906e+12
# 6                   Argentina  2009        7.062178e+11       1.411526e+12
# 7                   Argentina  2010        7.729666e+11       1.810830e+12
# 8                   Argentina  2011        8.377910e+11       2.312009e+12
# 9                   Argentina  2012        8.445081e+11       2.765575e+12
# 10                      Aruba  2008        3.293180e+09       4.997610e+09
# ...

# %% [markdown]
# ### Modificamos los valores nulos

# %% [markdown]
# Reemplazamos los registros en 0.0 por la estrategia de la media de la columna de cada indicador

# %%
from sklearn.preprocessing import Imputer
impute=Imputer(missing_values=0,strategy='mean',axis=0)
tabla2 = np.array(pd.read_csv("economia7.csv").drop('Unnamed: 0', 1))
impute.fit(tabla2)
tabla2_mejorada=impute.transform(tabla2)
pd.DataFrame(tabla2_mejorada).head()
# Out:
#              0             1             2             3           4   \
# 0  3.358406e+09  3.637845e+09  1.347350e+09  1.239080e+09  108.320559
# 1  2.954188e+09  3.257308e+09  1.206410e+09  1.089944e+09  110.260684
# 2  2.743171e+09  3.065955e+09  1.135539e+09  1.012090e+09  111.766847
# 3  2.693974e+09  3.050780e+09  1.129918e+09  9.939385e+08  113.244595
# 4  2.802259e+09  3.252725e+09  1.204713e+09  1.033890e+09  116.075112
#
#           5             6             7             8             9   \
# 0   0.071111  14517.635341  39348.639719  42622.666667  15786.172840
# 1 -12.036015  12629.713786  34231.611819  37744.009270  13979.262693
# 2  -7.142991  11602.142227  31446.478970  35146.738046  13017.310387
# 3  -1.793436  11275.280156  30560.551094  34608.172248  12817.841573
# 4   4.019542  11607.745344  31461.665675  36519.163794  13525.616220
#
#           10            11            12            13            14
# ...

# %% [markdown]
# ### Normalizamos los Datos

# %% [markdown]
# Normalizamos los datos de la tabla1 datos por medio de la siguiente función

# %%
def normalizar_datos(X):
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    Xr = sc.fit_transform(X)
    return Xr

# %%
Xr = normalizar_datos(tabla2_mejorada)
pd.DataFrame(Xr).head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.246991 -0.249311 -0.409047 -0.444492 -0.505522 -0.585838  1.667520
# 1 -0.246997 -0.249315 -0.409430 -0.445166 -0.501014 -4.024018  1.270671
# 2 -0.247000 -0.249317 -0.409622 -0.445517 -0.497515 -2.634498  1.054671
# 3 -0.247001 -0.249317 -0.409638 -0.445599 -0.494081 -1.115332  0.985963
# 4 -0.247000 -0.249315 -0.409435 -0.445419 -0.487505  0.535436  1.055849
#
#          7         8         9         10        11        12        13  \
# 0 -0.327716 -0.340342  1.187987 -0.633506  1.636987  1.548528 -0.433509
# 1 -0.330662 -0.341909  0.879764 -4.183113  1.182812  1.129494 -0.434027
# 2 -0.332265 -0.342743  0.715674 -2.738051  0.935610  0.920773 -0.434298
# 3 -0.332775 -0.342915  0.681649 -1.159204  0.856977  0.898339 -0.434361
# 4 -0.332256 -0.342302  0.802381  0.552326  0.936958  1.029988 -0.434222
#
#          14
# 0 -0.432375
# 1 -0.432855
# 2 -0.433080
# 3 -0.433071
# 4 -0.432864

# %% [markdown]
# # Cross Validation

# %% [markdown]
# Definimos una función de Cross Validation con k-folds=5

# %%
from sklearn.datasets import *
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
# %matplotlib inline

def crossval_estimator(estimator, X,y, n_folds=5):
    from sklearn.cross_validation import KFold
    sctr, scts = [],[]
    for itr, its in KFold(len(X), n_folds):
        
        X_train = X[itr]
        y_train = y[itr]
        X_test  = X[its]
        y_test  = y[its]

        estimator.fit(X_train,y_train)
        
        sctr.append(estimator.score(X_train,y_train))
        scts.append(estimator.score(X_test,y_test))
    
    return np.mean(sctr), np.std(sctr), np.mean(scts), np.std(scts)

from sklearn.tree import DecisionTreeClassifier

def crossval_estimators(estimators,X,y):
    meanstr, stdstr = [], []
    meansts, stdsts = [], []
    for estimator in estimators:
        mstr, sstr, msts, ssts = crossval_estimator(estimator, X, y)
        meanstr.append(mstr)
        stdstr.append(sstr)
        meansts.append(msts)
        stdsts.append(ssts)

    return [np.array(i) for i in meanstr, meansts, stdstr, stdsts]

rngs = range(1,15,1)
estimators = [DecisionTreeClassifier(max_depth=i) for i in rngs]

def plot_cv_estimators(estimators, rngs, X,y):
    meanstr, meansts, stdstr, stdsts = crossval_estimators(estimators,X,y)

    print meanstr[-1]
    print meansts[-1]
    
    plt.grid()
    plt.plot(rngs, meanstr, "o-", color="red", label="train")
    plt.fill_between(rngs, meanstr-stdstr, meanstr+stdstr, color="red", alpha=.2)

    plt.plot(rngs, meansts, "o-", color="green", label="test")
    plt.fill_between(rngs, meansts-stdsts, meansts+stdsts, color="green", alpha=.2)
    plt.xlabel("estimators")
    plt.ylabel("score")
    plt.legend(loc="best")
    plt.title("validation curve")
    
def cv_estimators_results(estimators,X,y):
    meanstr, meansts, stdstr, stdsts = crossval_estimators(estimators,X,y)
    return meansts[-1]

# %% [markdown]
# ### Matriz de Correlación

# %% [markdown]
# Calculamos la matriz de correlación, buscando determinar qué indicadores tienen mayor correlación

# %%
def correlation_matrix(df):
    from matplotlib import pyplot as plt
    from matplotlib import cm as cm

    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    cmap = cm.get_cmap('jet', 30)
    cax = ax1.imshow(df.corr(), interpolation="nearest", cmap=cmap)
    plt.title('Matriz de correlacion')
    fig.colorbar(cax)
    plt.show()

# %%
correlation_matrix(pd.DataFrame(Xr))

# %% [markdown]
# ### Pruebas

# %% [markdown]
# Intentamos predecir los indicadores comparando todos como X contra y (el indicador en cuestión)

# %% [markdown]
# Indicador 0 - 'GDP (constant LCU)'

# %%
X,y = Xr[:,:], np.asarray(Xr[:,0], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning:
#
# This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
# 0.939024390244
# 0.609756097561

# %% [markdown]
# Indicador 1 - 'GDP (current LCU)'

# %%
X,y = Xr[:,:], np.asarray(Xr[:,1], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.907317073171
# 0.634146341463

# %% [markdown]
# Indicador 2 - 'GDP (current US$)'

# %%
X,y = Xr[:,:], np.asarray(Xr[:,2], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.637804878049
# 0.268292682927

# %% [markdown]
# Indicador 3 - 'GDP at market prices (constant 2010 US$)'

# %%
X,y = Xr[:,:], np.asarray(Xr[:,3], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.751219512195
# 0.263414634146

# %% [markdown]
# Indicador 4 - 'GDP deflator (base year varies by country)'

# %%
X,y = Xr[:,:], np.asarray(Xr[:,4], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.69512195122
# 0.248780487805

# %% [markdown]
# Indicador 5 - 'GDP growth (annual %)'

# %%
X,y = Xr[:,:], np.asarray(Xr[:,5], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.431707317073
# 0.160975609756

# %% [markdown]
# Indicador 6 - 'GDP per capita (constant 2010 US$)'

# %%
X,y = Xr[:,:], np.asarray(Xr[:,6], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.440243902439
# 0.160975609756

# %% [markdown]
# Indicador 7 - 'GDP per capita (constant LCU)'

# %%
X,y = Xr[:,:], np.asarray(Xr[:,7], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.89512195122
# 0.414634146341

# %% [markdown]
# Indicador 8 - 'GDP per capita (current LCU)'

# %%
X,y = Xr[:,:], np.asarray(Xr[:,8], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.84756097561
# 0.624390243902

# %% [markdown]
# Indicador 9 - 'GDP per capita (current US$)'

# %%
X,y = Xr[:,:], np.asarray(Xr[:,9], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.392682926829
# 0.151219512195

# %% [markdown]
# Indicador 10 - 'GDP per capita growth (annual %)'

# %%
X,y = Xr[:,:], np.asarray(Xr[:,10], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.441463414634
# 0.160975609756

# %% [markdown]
# Indicador 11 - 'GDP per capita, PPP (constant 2011 international $)'

# %%
X,y = Xr[:,:], np.asarray(Xr[:,11], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.369512195122
# 0.146341463415

# %% [markdown]
# Indicador 12 - 'GDP per capita, PPP (current international $)'

# %%
X,y = Xr[:,:], np.asarray(Xr[:,12], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.45
# 0.146341463415

# %% [markdown]
# Indicador 13 - 'GDP, PPP (constant 2011 international $)'

# %%
X,y = Xr[:,:], np.asarray(Xr[:,13], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.779268292683
# 0.273170731707

# %% [markdown]
# ### Tabla de Resultados

# %% [markdown]
# Compilamos todos los resultados

# %%
resultados = []
for i in range(len(name_indicators)):
    X,y = Xr[:,:], np.asarray(Xr[:,i], dtype="|S6")
    resultados.append([name_indicators[i],cv_estimators_results(estimators,X,y)*100])
pd.DataFrame(resultados,columns=['Indicador','Test (%)'])
# Out:
#                                             Indicador   Test (%)
# 0                                  GDP (constant LCU)  58.048780
# 1                                   GDP (current LCU)  62.439024
# 2                                   GDP (current US$)  27.804878
# 3            GDP at market prices (constant 2010 US$)  24.878049
# 4          GDP deflator (base year varies by country)  23.414634
# 5                               GDP growth (annual %)  16.097561
# 6                  GDP per capita (constant 2010 US$)  16.097561
# 7                       GDP per capita (constant LCU)  41.951220
# 8                        GDP per capita (current LCU)  60.975610
# 9                        GDP per capita (current US$)  15.121951
# 10                   GDP per capita growth (annual %)  16.097561
# 11  GDP per capita, PPP (constant 2011 internation...  14.634146
# 12      GDP per capita, PPP (current international $)  14.634146
# ...

# %%
correlation_matrix(pd.DataFrame(Xr))

# %% [markdown]
# Comparando con la Matriz de Correlación podemos observar una clara correlación para los indicadores 0,1,7 y 8, que se validan con un alto grado de porcentaje en la tabla de resultados

# %% [markdown]
# ### Suramérica - Deuda Externa

# %%
def grafica_filtro_indicadores(continente,datos_continente,indicadores):
    suramerica_indicadores = filtro_indicadores(continente,datos_continente,indicadores)
    data = [
        go.Heatmap(
            z=suramerica_indicadores['Year'].values.tolist(),
            x=suramerica_indicadores['IndicatorName'].values.tolist(),
            y=suramerica_indicadores['CountryName'].values.tolist(),
            colorscale='Viridis'
        )
    ]
    return py.iplot(data, filename='Deuda Externa - Suramerica')
grafica_filtro_indicadores(suramerica,pd.read_csv("suramerica2.csv"),deuda)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ambigus9/134.embed" height="525px" width="100%"></iframe>

# %%
name_indicators = np.array(['Average grace period on new external debt commitments (years)','Average grace period on new external debt commitments, official (years)','Average grace period on new external debt commitments, private (years)','Average grant element on new external debt commitments (%)','Average grant element on new external debt commitments, official (%)','Average grant element on new external debt commitments, private (%)','Average interest on new external debt commitments (%)','Average interest on new external debt commitments, official (%)','Average interest on new external debt commitments, private (%)','Average maturity on new external debt commitments (years)','Average maturity on new external debt commitments, official (years)','Average maturity on new external debt commitments, private (years)'])
x_name_indicators = np.array(['Average grace period on new external debt commitments (years)','Average grace period on new external debt commitments, official (years)','Average grace period on new external debt commitments, private (years)','Average grant element on new external debt commitments (%)','Average grant element on new external debt commitments, official (%)','Average grant element on new external debt commitments, private (%)','Average interest on new external debt commitments (%)','Average interest on new external debt commitments, official (%)','Average interest on new external debt commitments, private (%)','Average maturity on new external debt commitments (years)','Average maturity on new external debt commitments, official (years)'])
y_name_indicator = np.array(['Average maturity on new external debt commitments, private (years)'])
x_indicators = np.array(['DT.GPA.DPPG','DT.GPA.OFFT','DT.GPA.PRVT','DT.GRE.DPPG','DT.GRE.OFFT','DT.GRE.PRVT','DT.INR.DPPG','DT.INR.OFFT','DT.INR.PRVT','DT.MAT.DPPG','DT.MAT.OFFT'])
y_indicator = np.array(['DT.MAT.PRVT'])
years = np.array([2008,2009,2010,2011,2012])

# %% [markdown]
# ### Suramérica - Deuda - Average - Tabla 1

# %%
start_time = time.time()

tabla1 = tabla_1(suramerica,pd.read_csv("suramerica.csv"),x_indicators,y_indicator,years)
tabla2 = np.array(zip(*tabla1[2:]))

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 494.411000013 seconds ---

# %%
pd.DataFrame(tabla2).to_csv('deuda7.csv')
pd.DataFrame(zip(*tabla1),columns=np.hstack((np.array(['Pais']),np.array(['Año']),x_name_indicators,y_name_indicator)))
# Out:
#                          Pais   Año  \
# 0         Antigua and Barbuda  2008
# 1         Antigua and Barbuda  2009
# 2         Antigua and Barbuda  2010
# 3         Antigua and Barbuda  2011
# 4         Antigua and Barbuda  2012
# 5                   Argentina  2008
# 6                   Argentina  2009
# 7                   Argentina  2010
# 8                   Argentina  2011
# 9                   Argentina  2012
# 10                      Aruba  2008
# 11                      Aruba  2009
# 12                      Aruba  2010
# 13                      Aruba  2011
# 14                      Aruba  2012
# 15               Bahamas, The  2008
# 16               Bahamas, The  2009
# 17               Bahamas, The  2010
# 18               Bahamas, The  2011
# 19               Bahamas, The  2012
# 20                   Barbados  2008
# 21                   Barbados  2009
# 22                   Barbados  2010
# 23                   Barbados  2011
# 24                   Barbados  2012
# ...

# %% [markdown]
# ### Pregunta:

# %% [markdown]
# - ¿Visualizar valores nulos de un conjunto de indicadores? (Confusión entre no registro y registro 0.0)
# - ¿Visualizar continuidad de registros para cada indicador por medio de señales? (Incertidumbre en elección de rango de Años)

# %% [markdown]
# ### Paises No Nulos

# %% [markdown]
# Buscamos determinar los paises No-nulos

# %%
paises_valores = []
tabla3 = np.array(zip(*tabla1))
for i in range(len(tabla2[:,0])):
    a = tabla2[i,0]
    b = tabla3[i,0]
    if a != 0:
        paises_valores.append(i)

tabla2_valores = []
for i in paises_valores:    
    tabla2_valores.append(tabla2[i])
pd.DataFrame(tabla2_valores).head()
# Out:
#        0       1     2        3        4        5       6       7     8   \
# 0  5.9389  5.3372  12.5  40.7730  40.3727  45.1384  4.1012  4.0876  4.25
# 1  4.5687  4.5687   0.0  54.6719  54.6719   0.0000  1.9352  1.9352  0.00
# 2  5.5306  5.5306   0.0  55.3044  55.3044   0.0000  2.0424  2.0424  0.00
# 3  5.0858  5.0858   0.0  45.3851  45.3851   0.0000  3.2758  3.2758  0.00
# 4  3.0211  3.0211   0.0  66.9211  66.9211   0.0000  0.1118  0.1118  0.00
#
#         9        10    11
# 0  22.6749  22.7368  22.0
# 1  22.1956  22.1956   0.0
# 2  22.8135  22.8135   0.0
# 3  21.5415  21.5415   0.0
# 4  24.6165  24.6165   0.0

# %% [markdown]
# Probamos que la función Imputer trabaja determinando la media sobre los valores con registros

# %%
tabla2_valores = np.array(tabla2_valores)
np.mean(tabla2_valores[:,0])
# Out:
# 6.2401845454545466

# %% [markdown]
# ### Pregunta:

# %% [markdown]
# ¿Es más eficiente eliminar paises sin registros que reemplazar sus registros 0 por la media de la columna?

# %% [markdown]
# ### Reemplazamos los valores nulos por la media de la columna (sin eliminar paises nulos)

# %%
from sklearn.preprocessing import Imputer
impute=Imputer(missing_values=0,strategy='mean',axis=0)
tabla2 = np.array(pd.read_csv("deuda7.csv").drop('Unnamed: 0', 1))
impute.fit(tabla2)
tabla2_mejorada=impute.transform(tabla2)
pd.DataFrame(tabla2_mejorada).head()
# Out:
#          0         1         2          3          4          5         6   \
# 0  6.240185  5.287975  9.842363  47.833797  52.155227  32.830647  2.849095
# 1  6.240185  5.287975  9.842363  47.833797  52.155227  32.830647  2.849095
# 2  6.240185  5.287975  9.842363  47.833797  52.155227  32.830647  2.849095
# 3  6.240185  5.287975  9.842363  47.833797  52.155227  32.830647  2.849095
# 4  6.240185  5.287975  9.842363  47.833797  52.155227  32.830647  2.849095
#
#          7         8          9          10         11
# 0  2.275406  4.628138  21.352545  22.145379  14.767939
# 1  2.275406  4.628138  21.352545  22.145379  14.767939
# 2  2.275406  4.628138  21.352545  22.145379  14.767939
# 3  2.275406  4.628138  21.352545  22.145379  14.767939
# 4  2.275406  4.628138  21.352545  22.145379  14.767939

# %% [markdown]
# ### Normalizamos los datos

# %%
Xr = normalizar_datos(tabla2_mejorada)
pd.DataFrame(Xr)
# Out:
#            0             1             2         3             4   \
# 0    0.000000  5.040551e-16 -5.028220e-16  0.000000  8.509911e-16
# 1    0.000000  5.040551e-16 -5.028220e-16  0.000000  8.509911e-16
# 2    0.000000  5.040551e-16 -5.028220e-16  0.000000  8.509911e-16
# 3    0.000000  5.040551e-16 -5.028220e-16  0.000000  8.509911e-16
# 4    0.000000  5.040551e-16 -5.028220e-16  0.000000  8.509911e-16
# 5    0.000000  5.040551e-16 -5.028220e-16  0.000000  8.509911e-16
# 6    0.000000  5.040551e-16 -5.028220e-16  0.000000  8.509911e-16
# 7    0.000000  5.040551e-16 -5.028220e-16  0.000000  8.509911e-16
# 8    0.000000  5.040551e-16 -5.028220e-16  0.000000  8.509911e-16
# 9    0.000000  5.040551e-16 -5.028220e-16  0.000000  8.509911e-16
# 10   0.000000  5.040551e-16 -5.028220e-16  0.000000  8.509911e-16
# 11   0.000000  5.040551e-16 -5.028220e-16  0.000000  8.509911e-16
# 12   0.000000  5.040551e-16 -5.028220e-16  0.000000  8.509911e-16
# ...

# %% [markdown]
# ### Matriz de Correlación

# %%
correlation_matrix(pd.DataFrame(tabla2_mejorada))

# %% [markdown]
# ### Pruebas

# %%
X,y = Xr[:,:], np.asarray(Xr[:,0], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.7
# 0.463414634146

# %%
X,y = Xr[:,:], np.asarray(Xr[:,1], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.629268292683
# 0.463414634146

# %%
X,y = Xr[:,:], np.asarray(Xr[:,2], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.919512195122
# 0.760975609756

# %% [markdown]
# ### Tabla de Resultados

# %%
resultados = []
for i in range(len(name_indicators)):
    X,y = Xr[:,:], np.asarray(Xr[:,i], dtype="|S6")
    resultados.append([name_indicators[i],cv_estimators_results(estimators,X,y)*100])
pd.DataFrame(resultados,columns=['Indicador','Test (%)'])
# Out:
#                                             Indicador   Test (%)
# 0   Average grace period on new external debt comm...  46.341463
# 1   Average grace period on new external debt comm...  46.341463
# 2   Average grace period on new external debt comm...  76.097561
# 3   Average grant element on new external debt com...  46.341463
# 4   Average grant element on new external debt com...  46.341463
# 5   Average grant element on new external debt com...  76.097561
# 6   Average interest on new external debt commitme...  47.317073
# 7   Average interest on new external debt commitme...  46.341463
# 8   Average interest on new external debt commitme...  76.097561
# 9   Average maturity on new external debt commitme...  46.341463
# 10  Average maturity on new external debt commitme...  46.341463
# 11  Average maturity on new external debt commitme...  76.097561

# %% [markdown]
# ### Reemplazamos los valores nulos por la media de la columna (Eliminando paises nulos)

# %%
from sklearn.preprocessing import Imputer
impute=Imputer(missing_values=0,strategy='mean',axis=0)
impute.fit(tabla2_valores)
tabla2_valores_mejorada=impute.transform(tabla2_valores)
pd.DataFrame(tabla2_valores_mejorada).head()
# Out:
#        0       1          2        3        4          5       6       7   \
# 0  5.9389  5.3372  12.500000  40.7730  40.3727  45.138400  4.1012  4.0876
# 1  4.5687  4.5687   9.842363  54.6719  54.6719  32.830647  1.9352  1.9352
# 2  5.5306  5.5306   9.842363  55.3044  55.3044  32.830647  2.0424  2.0424
# 3  5.0858  5.0858   9.842363  45.3851  45.3851  32.830647  3.2758  3.2758
# 4  3.0211  3.0211   9.842363  66.9211  66.9211  32.830647  0.1118  0.1118
#
#          8        9        10         11
# 0  4.250000  22.6749  22.7368  22.000000
# 1  4.628138  22.1956  22.1956  14.767939
# 2  4.628138  22.8135  22.8135  14.767939
# 3  4.628138  21.5415  21.5415  14.767939
# 4  4.628138  24.6165  24.6165  14.767939

# %% [markdown]
# ### Normalizamos los datos

# %%
Xr = normalizar_datos(tabla2_valores_mejorada)
pd.DataFrame(Xr).head()
# Out:
#          0         1             2         3         4             5   \
# 0 -0.080347  0.020464  5.510604e-01 -0.523400 -1.033696  9.530864e-01
# 1 -0.445754 -0.299015 -1.473309e-15  0.506892  0.220791  1.650688e-15
# 2 -0.189233  0.100863 -1.473309e-15  0.553777  0.276281  1.650688e-15
# 3 -0.307853 -0.084048 -1.473309e-15 -0.181516 -0.593952  1.650688e-15
# 4 -0.858470 -0.942377 -1.473309e-15  1.414895  1.295428  1.650688e-15
#
#          6         7         8         9         10            11
# 0  0.834566  1.499627 -0.266381  0.210859  0.115372  1.252087e+00
# 1 -0.609139 -0.281528  0.000000  0.134431  0.009797  2.152785e-15
# 2 -0.537687 -0.192818  0.000000  0.232960  0.130335  2.152785e-15
# 3  0.284412  0.827846  0.000000  0.030130 -0.117803  2.152785e-15
# 4 -1.824491 -1.790428  0.000000  0.520461  0.482058  2.152785e-15

# %% [markdown]
# ### Pruebas

# %%
X,y = Xr[:,:], np.asarray(Xr[:,0], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.213636363636
# 0.0

# %%
X,y = Xr[:,:], np.asarray(Xr[:,1], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.195454545455
# 0.0

# %%
X,y = Xr[:,:], np.asarray(Xr[:,2], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.843181818182
# 0.554545454545

# %%
X,y = Xr[:,:], np.asarray(Xr[:,3], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.270454545455
# 0.0

# %%
X,y = Xr[:,:], np.asarray(Xr[:,4], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.170454545455
# 0.0

# %% [markdown]
# ### Resultados

# %%
resultados = []
for i in range(len(name_indicators)):
    X,y = Xr[:,:], np.asarray(Xr[:,i], dtype="|S6")
    resultados.append([name_indicators[i],cv_estimators_results(estimators,X,y)*100])
pd.DataFrame(resultados,columns=['Indicador','Test (%)'])
# Out:
#                                             Indicador   Test (%)
# 0   Average grace period on new external debt comm...   0.000000
# 1   Average grace period on new external debt comm...   0.000000
# 2   Average grace period on new external debt comm...  55.454545
# 3   Average grant element on new external debt com...   0.000000
# 4   Average grant element on new external debt com...   0.000000
# 5   Average grant element on new external debt com...  55.454545
# 6   Average interest on new external debt commitme...   0.000000
# 7   Average interest on new external debt commitme...   0.000000
# 8   Average interest on new external debt commitme...  55.454545
# 9   Average maturity on new external debt commitme...   0.000000
# 10  Average maturity on new external debt commitme...   0.000000
# 11  Average maturity on new external debt commitme...  55.454545

# %% [markdown]
# ## Suramerica - Educación

# %%
def grafica_filtro_indicadores(continente,datos_continente,indicadores):
    suramerica_indicadores = filtro_indicadores(continente,datos_continente,indicadores)
    data = [
        go.Heatmap(
            z=suramerica_indicadores['Year'].values.tolist(),
            x=suramerica_indicadores['IndicatorName'].values.tolist(),
            y=suramerica_indicadores['CountryName'].values.tolist(),
            colorscale='Viridis'
        )
    ]
    return py.iplot(data, filename='Educación - Suramerica')
grafica_filtro_indicadores(suramerica,pd.read_csv("suramerica2.csv"),educacion)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ambigus9/136.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### Suramerica - Educación - Gross

# %%
name_indicators = np.array(['Gross enrollment ratio, primary, both sexes (%)','Gross enrolment ratio, pre-primary, both sexes (%)','Gross enrolment ratio, pre-primary, female (%)','Gross enrolment ratio, pre-primary, male (%)','Gross enrolment ratio, secondary, both sexes (%)','Gross enrolment ratio, tertiary, both sexes (%)','Gross intake ratio to Grade 1 of primary education, both sexes (%)','Gross intake ratio to Grade 1 of primary education, female (%)','Gross intake ratio to Grade 1 of primary education, male (%)'])
x_name_indicators = np.array(['Gross enrollment ratio, primary, both sexes (%)','Gross enrolment ratio, pre-primary, both sexes (%)','Gross enrolment ratio, pre-primary, female (%)','Gross enrolment ratio, pre-primary, male (%)','Gross enrolment ratio, secondary, both sexes (%)','Gross enrolment ratio, tertiary, both sexes (%)','Gross intake ratio to Grade 1 of primary education, both sexes (%)','Gross intake ratio to Grade 1 of primary education, female (%)'])
y_name_indicator = np.array(['Gross intake ratio to Grade 1 of primary education, male (%)'])
x_indicators = np.array(['SE.PRM.ENRR','SE.PRE.ENRR','SE.PRE.ENRR.FE','SE.PRE.ENRR.MA','SE.SEC.ENRR','SE.TER.ENRR','SE.PRM.GINT.ZS','SE.PRM.GINT.FE.ZS'])
y_indicator = np.array(['SE.PRM.GINT.MA.ZS'])
years = np.array([2008,2009,2010,2011,2012])

# %%
start_time = time.time()

tabla1 = tabla_1(suramerica,pd.read_csv("suramerica.csv"),x_indicators,y_indicator,years)
tabla2 = np.array(zip(*tabla1[2:]))

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 511.812000036 seconds ---

# %%
pd.DataFrame(tabla2).to_csv('educacion7.csv')
pd.DataFrame(zip(*tabla1),columns=np.hstack((np.array(['Pais']),np.array(['Año']),x_name_indicators,y_name_indicator)))
# Out:
#                          Pais   Año  \
# 0         Antigua and Barbuda  2008
# 1         Antigua and Barbuda  2009
# 2         Antigua and Barbuda  2010
# 3         Antigua and Barbuda  2011
# 4         Antigua and Barbuda  2012
# 5                   Argentina  2008
# 6                   Argentina  2009
# 7                   Argentina  2010
# 8                   Argentina  2011
# 9                   Argentina  2012
# 10                      Aruba  2008
# 11                      Aruba  2009
# 12                      Aruba  2010
# 13                      Aruba  2011
# 14                      Aruba  2012
# 15               Bahamas, The  2008
# 16               Bahamas, The  2009
# 17               Bahamas, The  2010
# 18               Bahamas, The  2011
# 19               Bahamas, The  2012
# 20                   Barbados  2008
# 21                   Barbados  2009
# 22                   Barbados  2010
# 23                   Barbados  2011
# 24                   Barbados  2012
# ...

# %% [markdown]
# ### Reemplazamos los valores nulos por la media de la columna

# %%
from sklearn.preprocessing import Imputer
impute=Imputer(missing_values=0,strategy='mean',axis=0)
tabla2 = np.array(pd.read_csv("educacion7.csv").drop('Unnamed: 0', 1))
impute.fit(tabla2)
tabla2_mejorada=impute.transform(tabla2)
pd.DataFrame(tabla2_mejorada).head()
# Out:
#             0          1          2          3           4          5  \
# 0  104.747238  77.500000  75.955200  79.040741  110.871239  42.685638
# 1  102.789429  74.613822  75.171216  74.091853  108.536278  14.810050
# 2  103.399490  84.323601  81.721153  86.959457  106.220100  16.231960
# 3  100.677048  82.672089  83.951447  81.377899  106.116547  14.368360
# 4   97.892860  88.630928  85.840714  91.438362  105.393509  23.486240
#
#             6           7           8
# 0  100.517799   97.897499  103.061218
# 1   92.141449   93.289467   91.003906
# 2   95.499672  102.092328  103.107582
# 3   93.708168   92.543282   94.885597
# 4   88.251183   85.637581   90.896744

# %% [markdown]
# ### Normalizamos los datos

# %%
Xr = normalizar_datos(tabla2_mejorada)
pd.DataFrame(Xr).head()
# Out:
#           0         1             2             3         4             5  \
# 0 -0.171907  0.150639  4.058076e-02  2.595383e-01  2.205328 -8.336054e-16
# 1 -0.442932  0.000000  7.355850e-16 -7.452707e-16  1.986023 -1.635175e+00
# 2 -0.358480  0.506783  3.390391e-01  6.748256e-01  1.768482 -1.551766e+00
# 3 -0.735355  0.420586  4.544840e-01  3.821077e-01  1.758756 -1.661085e+00
# 4 -1.120777  0.731596  5.522766e-01  9.097162e-01  1.690847 -1.126232e+00
#
#           6             7             8
# 0 -0.192151 -4.193595e-01 -4.112370e-03
# 1 -0.985564 -8.800271e-01 -1.073570e+00
# 2 -0.667471  2.841335e-15 -1.260472e-15
# 3 -0.837164 -9.546237e-01 -7.292725e-01
# 4 -1.354053 -1.644991e+00 -1.083075e+00

# %% [markdown]
# ### Matriz de Correlación

# %%
correlation_matrix(pd.DataFrame(tabla2_mejorada))

# %% [markdown]
# ### Pruebas

# %%
X,y = Xr[:,:], np.asarray(Xr[:,0], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.528048780488
# 0.331707317073

# %%
X,y = Xr[:,:], np.asarray(Xr[:,1], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.563414634146
# 0.356097560976

# %%
X,y = Xr[:,:], np.asarray(Xr[:,2], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.520731707317
# 0.356097560976

# %%
X,y = Xr[:,:], np.asarray(Xr[:,3], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.551219512195
# 0.356097560976

# %%
X,y = Xr[:,:], np.asarray(Xr[:,4], dtype="|S6")
plot_cv_estimators(estimators, rngs, X,y)
# Out:
# 0.531707317073
# 0.29756097561

# %% [markdown]
# ### Resultados

# %%
resultados = []
for i in range(len(name_indicators)):
    X,y = Xr[:,:], np.asarray(Xr[:,i], dtype="|S6")
    resultados.append([name_indicators[i],cv_estimators_results(estimators,X,y)*100])
pd.DataFrame(resultados,columns=['Indicador','Test (%)'])
# Out:
#                                            Indicador   Test (%)
# 0    Gross enrollment ratio, primary, both sexes (%)  33.170732
# 1  Gross enrolment ratio, pre-primary, both sexes...  35.609756
# 2     Gross enrolment ratio, pre-primary, female (%)  35.609756
# 3       Gross enrolment ratio, pre-primary, male (%)  35.609756
# 4   Gross enrolment ratio, secondary, both sexes (%)  29.756098
# 5    Gross enrolment ratio, tertiary, both sexes (%)  55.121951
# 6  Gross intake ratio to Grade 1 of primary educa...  37.560976
# 7  Gross intake ratio to Grade 1 of primary educa...  38.048780
# 8  Gross intake ratio to Grade 1 of primary educa...  38.536585

# %% [markdown]
# ## Aplicamos un PCA

# %%
tabla_economia = np.array(pd.read_csv("economia7.csv").drop('Unnamed: 0', 1))
pd.DataFrame(tabla_economia).head()
# Out:
#              0             1             2             3           4   \
# 0  3.358406e+09  3.637845e+09  1.347350e+09  1.239080e+09  108.320559
# 1  2.954188e+09  3.257308e+09  1.206410e+09  1.089944e+09  110.260684
# 2  2.743171e+09  3.065955e+09  1.135539e+09  1.012090e+09  111.766847
# 3  2.693974e+09  3.050780e+09  1.129918e+09  9.939385e+08  113.244595
# 4  2.802259e+09  3.252725e+09  1.204713e+09  1.033890e+09  116.075112
#
#           5             6             7             8             9   \
# 0   0.071111  14517.635341  39348.639719  42622.666667  15786.172840
# 1 -12.036015  12629.713786  34231.611819  37744.009270  13979.262693
# 2  -7.142991  11602.142227  31446.478970  35146.738046  13017.310387
# 3  -1.793436  11275.280156  30560.551094  34608.172248  12817.841573
# 4   4.019542  11607.745344  31461.665675  36519.163794  13525.616220
#
#           10            11            12            13            14
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(tabla_economia[:,:], tabla_economia[:,-1], test_size=0.33, random_state=42)

# Encontrar PCA economia
from sklearn.decomposition import PCA
pca_economia = PCA(n_components = 3)
pca_economia.fit(X_train)

X_train_pca = pca_economia.transform(X_train)
X_test_pca = pca_economia.transform(X_test)
