# %%
import numpy as np
import pandas as pd
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

plotly.tools.set_credentials_file(username='ambigus9', api_key='VIIp594gf158yUUVfCUK')

filtro1 = list()
filtro2 = list()
filtro3 = list()

datos = pd.read_csv("world-development-indicators/Indicators.csv")
datos
# Out:
#         CountryName CountryCode  \
# 0        Arab World         ARB
# 1        Arab World         ARB
# 2        Arab World         ARB
# 3        Arab World         ARB
# 4        Arab World         ARB
# 5        Arab World         ARB
# 6        Arab World         ARB
# 7        Arab World         ARB
# 8        Arab World         ARB
# 9        Arab World         ARB
# 10       Arab World         ARB
# 11       Arab World         ARB
# 12       Arab World         ARB
# 13       Arab World         ARB
# 14       Arab World         ARB
# 15       Arab World         ARB
# 16       Arab World         ARB
# 17       Arab World         ARB
# 18       Arab World         ARB
# 19       Arab World         ARB
# 20       Arab World         ARB
# 21       Arab World         ARB
# 22       Arab World         ARB
# 23       Arab World         ARB
# 24       Arab World         ARB
# 25       Arab World         ARB
# 26       Arab World         ARB
# 27       Arab World         ARB
# ...

# %%
paises = np.array(['Antigua and Barbuda','Argentina','Aruba','Bahamas, The','Barbados','Belize','Bolivia','Brazil','Cayman Islands','Chile','Colombia','Costa Rica','Cuba','Curacao','Dominica','Dominican Republic','Ecuador','El Salvador','Grenada','Guatemala','Guyana','Haiti','Honduras','Jamaica','Mexico','Nicaragua','Panama','Paraguay','Peru','Puerto Rico','Sint Maarten (Dutch part)','St. Kitts and Nevis','St. Vincent and the Grenadines','St. Lucia','St. Martin (French part)','Suriname','Trinidad and Tobago','Turks and Caicos Islands','Uruguay','Venezuela, RB','Virgin Islands (U.S.)'])
indicadores = np.array(['EG.ELC.ACCS.RU.ZS','EG.NSF.ACCS.RU.ZS'])
years = np.array([20011,2012])

# %%
temporal = list()
output = {}

for k in range(len(datos)):
    cn = datos['CountryName'][k]
    ic = datos['IndicatorCode'][k]
    y = datos['Year'][k]
    v = datos['Value'][k]

    if cn in paises and ic in indicadores and y in years:
        #country_name = datos['CountryName'][k]
        indicator_name = datos['IndicatorName'][k]
        #year = datos['Year'][k]

        if cn not in output.keys():
            output[cn] = []
        output[cn].append(np.array([cn,y,indicator_name,v]))
        
for p in paises:
    if p not in output.keys():
        temporal.append(np.array([cn,y,indicator_name,0]))
        
for o in output:
    temporal.append(np.array([o]))

temporal = sorted(temporal,key=lambda x:x[0]) 

for i in temporal: filtro1.append(i[0])
for i in temporal: filtro2.append(i[1])
for i in temporal: filtro3.append(i[2])
for i in temporal: filtro4.append(i[3])

temporal
